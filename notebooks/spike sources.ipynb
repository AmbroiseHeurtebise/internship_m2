# %%
import numpy as np
import matplotlib.pyplot as plt
from picard import picard

# %%
from delay_multiviewica import delay_multiviewica

# %%
from delay_multiviewica.optimization_tau import _optimization_tau, _apply_delay, _apply_delay_one_sub

# %%
p = 2
n = 400
m = 2
S = np.random.randn(p, n)
S[np.random.rand(p, n) < .9] = 0
delays = np.random.randint(0, n, m)
delays = (delays - delays[0]) % n
A_list = np.random.randn(m, p, p)
X_list = np.array([A @ S for A in A_list])
X_list = _apply_delay(X_list, delays)
print(n - delays)
# Out:
# [400 270]

# %%
_, tau_list, _ = _optimization_tau(X_list, 3)
print(tau_list)
# Out:
# [  0 273]

# %%
P, W, Se, tau_list = delay_multiviewica(X_list)
# Out:
# [  0 122]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# [ 0 18]
# [  0 122]
# ...

# %%
plt.plot(Se.T)

# %%
plt.scatter(Se[0], Se[1])

# %%
plt.plot(S.T)

# %%
plt.scatter(S[0], S[1])

# %%
plt.imshow(S @ Se.T)

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
from sklearn.utils import check_random_state
from sklearn.metrics import r2_score
from scipy.optimize import fmin_l_bfgs_b
from scipy import stats
from tqdm import tqdm

import jax
import jax.numpy as jnp

from picard import amari_distance

from multiviewica_delay import multiviewica_delay

# %% [markdown]
# # parameters

# %%
m = 10
p = 5
n = 600
max_shift = 20
max_dilation = 1.2
t0 = 0
noise_data = 0.01
noise_model = 1
noise_W_list = 0.1
bounds_factor = 1.2
filter_length = 3
number_of_filters = 1
time_params_scale = 0.2
random_state = 5724210

# %%
if max_shift != 0 and max_dilation != 1.:
    dilation_scale = 2 * max_shift / (max_dilation - 1 / max_dilation)
else:
    dilation_scale = 1.

max_dilation_2 = 1 + bounds_factor * (max_dilation - 1)
max_shift_2 = bounds_factor * max_shift

# %% [markdown]
# # apply delay functions

# %%
# def apply_both_delays_1d_cyclic(
#     s,
#     a,
#     b,
#     max_shift=0.,
#     max_dilation=1.,
#     dilation_scale=1.,
#     t0=0,
#     shift_before_dilation=True,
# ):
#     n = len(s)
#     max_delay = (np.ceil((n + max_shift) * max_dilation) - n).astype("int")
#     s_extended = jnp.concatenate([s[n-max_delay:], s, s[:max_delay]])
#     t_extended = jnp.arange(n + 2 * max_delay) - max_delay - t0
#     t = jnp.arange(n) - t0
#     if shift_before_dilation:
#         t_ab = (t - b) * a / dilation_scale
#     else:
#         t_ab = t * a / dilation_scale - b
#     s_ab = jnp.interp(x=t_ab, xp=t_extended, fp=s_extended, left=0, right=0)
#     return s_ab

def apply_both_delays_2d_cyclic(
    S,
    a,
    b,
    max_shift=0.,
    max_dilation=1.,
    dilation_scale=1.,
    time_params_scale=1.,
    t0=0,
    shift_before_dilation=True,
):
    p, n = S.shape
    max_delay = (np.ceil((n + max_shift) * max_dilation) - n).astype("int")
    S_extended = jnp.concatenate([S[:, n-max_delay:], S, S[:, :max_delay]], axis=1)
    t_extended = jnp.arange(n + 2 * max_delay) - max_delay - t0
    t = jnp.arange(n) - t0
    T = jnp.array([t] * p)
    a_ = a / (dilation_scale * time_params_scale)
    b_ = b / time_params_scale
    if shift_before_dilation:
        # T_ab = ((T.T - b) * a / dilation_scale).T
        T_ab = ((T.T - b_) * a_).T
    else:
        # T_ab = (T.T * a / dilation_scale - b).T
        T_ab = (T.T * a_ - b_).T
    S_ab = jnp.array(
        [jnp.interp(x=T_ab[i], xp=t_extended, fp=S_extended[i], left=0, right=0)
         for i in range(p)])
    return S_ab

def apply_both_delays_3d_cyclic(
    S_list,
    A,
    B,
    max_shift=0.,
    max_dilation=1.,
    dilation_scale=1.,
    time_params_scale=1.,
    t0=0,
    shift_before_dilation=True,
):
    Y_list = jnp.array(
        [apply_both_delays_2d_cyclic(
            S_list[i], a=A[i], b=B[i], max_shift=max_shift, max_dilation=max_dilation, 
            dilation_scale=dilation_scale, time_params_scale=time_params_scale,
            t0=t0, shift_before_dilation=shift_before_dilation)
         for i in range(len(S_list))])
    return Y_list

# %% [markdown]
# # generate data

# %%
def sources_generation_zero_mean(p, n, rng=None):
    low_mean = n / 4
    high_mean = 6 * n / 10
    means = (np.arange(p) + rng.uniform(size=p)) * (high_mean - low_mean) / p + low_mean
    rng.shuffle(means)
    variances = rng.randint(n // 25, n // 10, size=p)
    heights = rng.uniform(0.6, 1.4, size=p)

    def f(x, mean, var):
        t = (x - mean) / var
        t[t > 0] /= 2
        s = -t/2 * np.exp(-t ** 2)
        s[s < 0] /= 2
        return s

    S = np.array(
        [height * f(np.arange(n), mean, var)
         for height, mean, var in zip(heights, means, variances)])
    return S

def data_generation(
    m,
    p,
    n,
    max_shift=0.,
    max_dilation=1.,
    noise_data=0.05,
    t0=0,
    rng=None,
):
    S = sources_generation_zero_mean(p, n, rng)
    S_list = np.array([S] * m) + noise_data * rng.randn(m, p, n)
    A_list = rng.randn(m, p, p)
    dilations = rng.uniform(low=1/max_dilation, high=max_dilation, size=(m, p))
    shifts = rng.uniform(low=-max_shift, high=max_shift, size=(m, p))
    S_list = apply_both_delays_3d_cyclic(
        S_list, A=dilations, B=shifts, max_shift=max_shift, max_dilation=max_dilation,
        dilation_scale=1., time_params_scale=1., t0=t0)
    X_list = np.array([np.dot(A, S) for A, S in zip(A_list, S_list)])
    return X_list, A_list, dilations, shifts, S_list, S

# %%
# generate data
rng = check_random_state(random_state)
X_list, A_list, dilations, shifts, S_list, S = data_generation(
    m=m,
    p=p,
    n=n,
    max_shift=max_shift,
    max_dilation=max_dilation,
    noise_data=noise_data,
    t0=t0,
    rng=rng,
)

# %% [markdown]
# # plot data

# %%
plt.figure(figsize=(8, 6))
plt.plot(S.T)
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.title("Original sources")
plt.grid()
plt.show()

# %%
# plot 2 sources of 2 subjects
plt.subplots(m, p, figsize=(4*m, 6*p))

for i in range(m):
    for j in range(p):
        plt.subplot(m, p, p * i + j + 1)
        plt.plot(S_list[i, j], label=f'a={dilations[i, j]:.2f} ; b={shifts[i, j]:.2f}')
        # plt.vlines(x=t0, ymin=np.min(S_list), ymax=np.max(S_list), linestyles='--', colors='grey')
        plt.ylim([np.min(S_list), np.max(S_list)])
        if j == 0:
            plt.ylabel(f"Subject {i}")
        if i == 1:
            plt.xlabel(f"Source {j}")
        plt.legend()
plt.suptitle(f"{m} subjects and {p} sources")
plt.tight_layout()
plt.show()

# %% [markdown]
# # loss and grad

# %%
jax.config.update('jax_enable_x64', True)

# %%
def penalization(A, B, dilation_scale=1., time_params_scale=1.):
    A_ = A / (dilation_scale * time_params_scale)
    B_ = B / time_params_scale
    
    pen_A = jnp.sum(
        jnp.mean(2 * (A_ - 1) / (max_dilation_2 - 1 / max_dilation_2), axis=0) ** 2)
    pen_B = jnp.sum(jnp.mean(B_ / (max_shift_2), axis=0) ** 2)
    return pen_A + pen_B

def smoothing_filter_3d(S_list):
    m, p, n = S_list.shape
    filter = np.ones(filter_length) / filter_length
    S_list_smooth = jnp.zeros((m, p, n))
    for i in range(m):
        S_list_smooth = S_list_smooth.at[i].set(
            jnp.array([jnp.convolve(s, filter, mode='same') for s in S_list[i]]))
    return S_list_smooth

def _logcosh(X):
    Y = jnp.abs(X)
    return Y + jnp.log1p(jnp.exp(-2 * Y))

# %%
def loss(W_A_B, X_list, dilation_scale, t0, noise_model):
    _, p, _ = X_list.shape
    W_list = W_A_B[:m*p**2].reshape((m, p, p))
    A = W_A_B[m*p**2: m*p*(p+1)].reshape((m, p))
    B = W_A_B[m*p*(p+1):].reshape((m, p))
    S_list = jnp.array([jnp.dot(W, X) for W, X in zip(W_list, X_list)])
    Y_list = apply_both_delays_3d_cyclic(
            S_list, A=A, B=B, max_shift=max_shift_2, 
            max_dilation=max_dilation_2, dilation_scale=dilation_scale,
            time_params_scale=time_params_scale, t0=t0, shift_before_dilation=False,
        )
    for _ in range(number_of_filters):
        Y_list = smoothing_filter_3d(Y_list)
    Y_avg = jnp.mean(Y_list, axis=0)
    loss = jnp.mean(_logcosh(Y_avg)) * p
    lambd = 1 / (2 * noise_model) * noise_data ** 2 * p * m
    loss += lambd * penalization(A, B, dilation_scale=dilation_scale, time_params_scale=time_params_scale)
    loss += 1 / (2 * noise_model) * jnp.sum(
        jnp.array([jnp.mean((Y - Y_avg) ** 2) for Y in Y_list])) * p
    for W in W_list:
        loss -= jnp.linalg.slogdet(W)[1]
    return loss

# %%
val_and_grad = jax.jit(jax.value_and_grad(loss))

def wrapper_loss_and_grad(W_A_B, X_list, dilation_scale, t0, noise_model):
    loss, grad = val_and_grad(W_A_B, X_list, dilation_scale, t0, noise_model)
    return loss, np.array(grad)

# %% [markdown]
# # jit

# %%
# initialization parameters
W_list_true = np.array([np.linalg.inv(A) for A in A_list])
W_list_init = W_list_true + noise_W_list * rng.randn(m, p, p)
A_init = jnp.ones((m, p)) * dilation_scale * time_params_scale
B_init = jnp.zeros((m, p))
W_A_B_init = jnp.concatenate([jnp.ravel(W_list_init), jnp.ravel(A_init), jnp.ravel(B_init)])

# %%
# jit
print("Jit...")
start = time()
wrapper_loss_and_grad(
    W_A_B_init,
    X_list,
    dilation_scale,
    t0,
    noise_model,
)
print(f"Jit time : {time() - start}")
# Out:
# Jit...
# Jit time : 33.52877187728882

# %% [markdown]
# # LBFGSB

# %%
# bounds
bounds_W = [(-jnp.inf, jnp.inf)] * (m * p ** 2)
bounds_A = [(1/max_dilation_2*dilation_scale*time_params_scale, max_dilation_2*dilation_scale*time_params_scale)] * (m * p)
bounds_B = [(-max_shift_2*time_params_scale, max_shift_2*time_params_scale)] * (m * p)
bounds_W_A_B = jnp.array(bounds_W + bounds_A + bounds_B)

# %%
class Memory_callback():
    def __init__(self):
        self.memory_W = []
        self.memory_A = []
        self.memory_B = []
    
    def __call__(self, W_A_B):
        self.memory_W.append(W_A_B[:m*p**2].reshape((m, p, p)))
        self.memory_A.append(W_A_B[m*p**2: m*p*(p+1)].reshape((m, p)) / (dilation_scale * time_params_scale))
        self.memory_B.append(W_A_B[m*p*(p+1):].reshape((m, p)) / time_params_scale)

# %%
# LBFGSB
callback = Memory_callback()

print("LBFGSB...")
start = time()
res = fmin_l_bfgs_b(
    func=wrapper_loss_and_grad,
    x0=W_A_B_init,
    args=(X_list, dilation_scale, t0, noise_model),
    bounds=bounds_W_A_B,
    disp=True,
    factr=1e9,
    pgtol=1e-8,
    callback=callback,
)
print(f"LBFGSB time : {time() - start}")
# Out:
# LBFGSB...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          350     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.80343D+01    |proj g|=  1.04042D+01
#
# At iterate    1    f=  6.55085D+00    |proj g|=  1.94588D+00
#
# At iterate    2    f= -1.52589D+00    |proj g|=  1.40413D+00
#
# At iterate    3    f= -2.15823D+01    |proj g|=  7.84789D-01
#
# At iterate    4    f= -4.02110D+01    |proj g|=  4.76428D-01
#
# At iterate    5    f= -6.02045D+01    |proj g|=  2.62615D-01
#
# At iterate    6    f= -7.98032D+01    |proj g|=  1.48570D-01
#
# At iterate    7    f= -1.01170D+02    |proj g|=  4.01770D-01
#
# At iterate    8    f= -1.09858D+02    |proj g|=  7.27824D-01
#
# At iterate    9    f= -1.20268D+02    |proj g|=  3.41031D-01
#
# At iterate   10    f= -1.24777D+02    |proj g|=  6.75765D-01
#
# At iterate   11    f= -1.30746D+02    |proj g|=  4.45048D-01
#
# At iterate   12    f= -1.35872D+02    |proj g|=  4.45418D-01
#
# At iterate   13    f= -1.40166D+02    |proj g|=  1.42851D+00
#
# At iterate   14    f= -1.42348D+02    |proj g|=  4.56075D-01
#
# At iterate   15    f= -1.43043D+02    |proj g|=  1.66903D+00
#
# At iterate   16    f= -1.44789D+02    |proj g|=  6.13901D-01
#
# At iterate   17    f= -1.46350D+02    |proj g|=  4.44845D-01
#
# At iterate   18    f= -1.47426D+02    |proj g|=  1.06746D+00
#
# At iterate   19    f= -1.49576D+02    |proj g|=  7.05441D-01
#
# At iterate   20    f= -1.50383D+02    |proj g|=  9.31596D-01
#
# At iterate   21    f= -1.51387D+02    |proj g|=  7.45197D-01
#
# At iterate   22    f= -1.51899D+02    |proj g|=  4.62090D-01
#
# At iterate   23    f= -1.52243D+02    |proj g|=  8.93227D-01
#
# At iterate   24    f= -1.52444D+02    |proj g|=  7.18647D-01
#
# At iterate   25    f= -1.53074D+02    |proj g|=  4.64648D-01
#
# At iterate   26    f= -1.53839D+02    |proj g|=  5.69008D-01
#
# At iterate   27    f= -1.54277D+02    |proj g|=  8.02776D-01
#
# At iterate   28    f= -1.54817D+02    |proj g|=  5.16227D-01
#
# At iterate   29    f= -1.55175D+02    |proj g|=  7.00781D-01
#
# At iterate   30    f= -1.55361D+02    |proj g|=  9.63264D-01
#
# At iterate   31    f= -1.55930D+02    |proj g|=  5.41167D-01
#
# At iterate   32    f= -1.56177D+02    |proj g|=  1.03004D+00
#
# At iterate   33    f= -1.56264D+02    |proj g|=  3.66872D-01
#
# At iterate   34    f= -1.56575D+02    |proj g|=  2.97484D-01
#
# At iterate   35    f= -1.56894D+02    |proj g|=  8.01606D-01
#
# At iterate   36    f= -1.57306D+02    |proj g|=  4.05083D-01
#
# At iterate   37    f= -1.57791D+02    |proj g|=  7.69045D-01
#
# At iterate   38    f= -1.58096D+02    |proj g|=  4.72989D-01
#
# At iterate   39    f= -1.58492D+02    |proj g|=  6.16660D-01
#
# At iterate   40    f= -1.58541D+02    |proj g|=  7.36920D-01
#
# At iterate   41    f= -1.59222D+02    |proj g|=  8.84145D-01
#
# At iterate   42    f= -1.59674D+02    |proj g|=  5.69119D-01
#
# At iterate   43    f= -1.59790D+02    |proj g|=  7.11247D-01
#
# At iterate   44    f= -1.60054D+02    |proj g|=  4.02038D-01
#
# At iterate   45    f= -1.60230D+02    |proj g|=  5.78554D-01
#
# At iterate   46    f= -1.60304D+02    |proj g|=  3.85632D-01
#
# At iterate   47    f= -1.60409D+02    |proj g|=  5.05733D-01
#
# At iterate   48    f= -1.60498D+02    |proj g|=  5.72085D-01
#
# At iterate   49    f= -1.60588D+02    |proj g|=  5.21760D-01
#
# At iterate   50    f= -1.60593D+02    |proj g|=  5.79894D-01
#
# At iterate   51    f= -1.60721D+02    |proj g|=  3.46625D-01
#
# At iterate   52    f= -1.60909D+02    |proj g|=  4.14096D-01
#
# At iterate   53    f= -1.61076D+02    |proj g|=  5.85527D-01
#
# At iterate   54    f= -1.61339D+02    |proj g|=  5.34372D-01
#
# At iterate   55    f= -1.61791D+02    |proj g|=  6.59648D-01
#
# At iterate   56    f= -1.62157D+02    |proj g|=  6.02026D-01
#
# At iterate   57    f= -1.62413D+02    |proj g|=  4.70766D-01
#
# At iterate   58    f= -1.62565D+02    |proj g|=  4.85311D-01
#
# At iterate   59    f= -1.62680D+02    |proj g|=  3.82192D-01
#
# At iterate   60    f= -1.62812D+02    |proj g|=  3.18126D-01
#
# At iterate   61    f= -1.62906D+02    |proj g|=  4.00503D-01
#
# At iterate   62    f= -1.62964D+02    |proj g|=  4.25958D-01
#
# At iterate   63    f= -1.63017D+02    |proj g|=  5.35209D-01
#
# At iterate   64    f= -1.63111D+02    |proj g|=  6.62574D-01
#
# At iterate   65    f= -1.63143D+02    |proj g|=  8.24633D-01
#
# At iterate   66    f= -1.63172D+02    |proj g|=  4.09489D-01
#
# At iterate   67    f= -1.63297D+02    |proj g|=  3.75958D-01
#
# At iterate   68    f= -1.63367D+02    |proj g|=  6.52873D-01
#
# At iterate   69    f= -1.63467D+02    |proj g|=  3.90619D-01
#
# At iterate   70    f= -1.63564D+02    |proj g|=  3.61380D-01
#
# At iterate   71    f= -1.63677D+02    |proj g|=  4.83449D-01
#
# At iterate   72    f= -1.63828D+02    |proj g|=  5.33083D-01
#
# At iterate   73    f= -1.64048D+02    |proj g|=  5.25907D-01
#
# At iterate   74    f= -1.64106D+02    |proj g|=  6.30198D-01
#
# At iterate   75    f= -1.64283D+02    |proj g|=  3.75283D-01
#
# At iterate   76    f= -1.64392D+02    |proj g|=  4.98023D-01
#
# At iterate   77    f= -1.64429D+02    |proj g|=  6.33411D-01
#
# At iterate   78    f= -1.64554D+02    |proj g|=  4.56501D-01
#
# At iterate   79    f= -1.64630D+02    |proj g|=  3.87857D-01
#
# At iterate   80    f= -1.64684D+02    |proj g|=  5.14900D-01
#
# At iterate   81    f= -1.64755D+02    |proj g|=  3.28760D-01
#
# At iterate   82    f= -1.64785D+02    |proj g|=  5.44319D-01
#
# At iterate   83    f= -1.64834D+02    |proj g|=  3.29146D-01
#
# At iterate   84    f= -1.64846D+02    |proj g|=  5.17742D-01
#
# At iterate   85    f= -1.64885D+02    |proj g|=  4.15893D-01
#
# At iterate   86    f= -1.64913D+02    |proj g|=  5.46926D-01
#
# At iterate   87    f= -1.64950D+02    |proj g|=  8.25254D-01
#
# At iterate   88    f= -1.64985D+02    |proj g|=  5.20445D-01
#
# At iterate   89    f= -1.65016D+02    |proj g|=  3.94713D-01
#
# At iterate   90    f= -1.65052D+02    |proj g|=  6.29305D-01
#
# At iterate   91    f= -1.65081D+02    |proj g|=  6.98080D-01
#
# At iterate   92    f= -1.65118D+02    |proj g|=  3.45828D-01
#
# At iterate   93    f= -1.65159D+02    |proj g|=  4.97162D-01
#
# At iterate   94    f= -1.65267D+02    |proj g|=  8.20166D-01
#
# At iterate   95    f= -1.65443D+02    |proj g|=  6.05679D-01
#
# At iterate   96    f= -1.65556D+02    |proj g|=  4.53918D-01
#
# At iterate   97    f= -1.65656D+02    |proj g|=  5.70549D-01
#
# At iterate   98    f= -1.65746D+02    |proj g|=  6.42412D-01
#
# At iterate   99    f= -1.65806D+02    |proj g|=  3.93223D-01
#
# At iterate  100    f= -1.65858D+02    |proj g|=  3.81884D-01
#
# At iterate  101    f= -1.65951D+02    |proj g|=  3.56557D-01
#
# At iterate  102    f= -1.66025D+02    |proj g|=  5.36339D-01
#
# At iterate  103    f= -1.66117D+02    |proj g|=  3.05828D-01
#
# At iterate  104    f= -1.66185D+02    |proj g|=  7.47474D-01
#
# At iterate  105    f= -1.66201D+02    |proj g|=  4.88454D-01
#
# At iterate  106    f= -1.66210D+02    |proj g|=  5.42225D-01
#
# At iterate  107    f= -1.66230D+02    |proj g|=  3.08957D-01
#
# At iterate  108    f= -1.66262D+02    |proj g|=  3.25276D-01
#
# At iterate  109    f= -1.66276D+02    |proj g|=  3.27989D-01
#
# At iterate  110    f= -1.66283D+02    |proj g|=  4.07763D-01
#
# At iterate  111    f= -1.66289D+02    |proj g|=  4.49946D-01
#
# At iterate  112    f= -1.66320D+02    |proj g|=  4.39720D-01
#
# At iterate  113    f= -1.66337D+02    |proj g|=  3.16351D-01
#
# At iterate  114    f= -1.66356D+02    |proj g|=  2.75624D-01
#
# At iterate  115    f= -1.66362D+02    |proj g|=  4.05774D-01
#
# At iterate  116    f= -1.66375D+02    |proj g|=  4.21004D-01
#
# At iterate  117    f= -1.66388D+02    |proj g|=  2.20188D-01
#
# At iterate  118    f= -1.66401D+02    |proj g|=  4.14769D-01
#
# At iterate  119    f= -1.66424D+02    |proj g|=  3.49263D-01
#
# At iterate  120    f= -1.66446D+02    |proj g|=  5.33493D-01
#
# At iterate  121    f= -1.66462D+02    |proj g|=  2.53008D-01
#
# At iterate  122    f= -1.66488D+02    |proj g|=  5.77871D-01
#
# At iterate  123    f= -1.66508D+02    |proj g|=  3.87809D-01
#
# At iterate  124    f= -1.66541D+02    |proj g|=  2.45102D-01
#
# At iterate  125    f= -1.66593D+02    |proj g|=  4.89295D-01
#
# At iterate  126    f= -1.66610D+02    |proj g|=  2.73132D-01
#
# At iterate  127    f= -1.66640D+02    |proj g|=  2.33497D-01
#
# At iterate  128    f= -1.66695D+02    |proj g|=  3.33551D-01
#
# At iterate  129    f= -1.66768D+02    |proj g|=  4.09842D-01
#
# At iterate  130    f= -1.66799D+02    |proj g|=  4.07351D-01
#
# At iterate  131    f= -1.66858D+02    |proj g|=  3.24618D-01
#
# At iterate  132    f= -1.66936D+02    |proj g|=  2.64376D-01
#
# At iterate  133    f= -1.66981D+02    |proj g|=  4.94768D-01
#
# At iterate  134    f= -1.67003D+02    |proj g|=  3.01768D-01
#
# At iterate  135    f= -1.67027D+02    |proj g|=  2.75894D-01
#
# At iterate  136    f= -1.67047D+02    |proj g|=  7.29455D-01
#
# At iterate  137    f= -1.67064D+02    |proj g|=  5.79409D-01
#
# At iterate  138    f= -1.67089D+02    |proj g|=  2.62716D-01
#
# At iterate  139    f= -1.67114D+02    |proj g|=  1.93236D-01
#
# At iterate  140    f= -1.67149D+02    |proj g|=  4.07043D-01
#
# At iterate  141    f= -1.67179D+02    |proj g|=  2.79423D-01
#
# At iterate  142    f= -1.67209D+02    |proj g|=  4.59661D-01
#
# At iterate  143    f= -1.67230D+02    |proj g|=  6.55975D-01
#
# At iterate  144    f= -1.67310D+02    |proj g|=  2.90776D-01
#
# At iterate  145    f= -1.67360D+02    |proj g|=  4.05121D-01
#
# At iterate  146    f= -1.67366D+02    |proj g|=  5.70217D-01
#
# At iterate  147    f= -1.67416D+02    |proj g|=  5.33604D-01
#
# At iterate  148    f= -1.67516D+02    |proj g|=  3.71148D-01
#
# At iterate  149    f= -1.67619D+02    |proj g|=  2.83183D-01
#
# At iterate  150    f= -1.67717D+02    |proj g|=  5.19868D-01
#
# At iterate  151    f= -1.67740D+02    |proj g|=  2.86037D-01
#
# At iterate  152    f= -1.67773D+02    |proj g|=  5.19943D-01
#
# At iterate  153    f= -1.67790D+02    |proj g|=  6.32167D-01
#
# At iterate  154    f= -1.67826D+02    |proj g|=  2.34140D-01
#
# At iterate  155    f= -1.67861D+02    |proj g|=  3.47827D-01
#
# At iterate  156    f= -1.67862D+02    |proj g|=  6.08981D-01
#
# At iterate  157    f= -1.67886D+02    |proj g|=  2.79342D-01
#
# At iterate  158    f= -1.67892D+02    |proj g|=  4.63977D-01
#
# At iterate  159    f= -1.67906D+02    |proj g|=  2.78035D-01
#
# At iterate  160    f= -1.67916D+02    |proj g|=  3.67014D-01
#
# At iterate  161    f= -1.67919D+02    |proj g|=  2.50268D-01
#
# At iterate  162    f= -1.67940D+02    |proj g|=  4.65815D-01
#
# At iterate  163    f= -1.67956D+02    |proj g|=  3.23751D-01
#
# At iterate  164    f= -1.67976D+02    |proj g|=  5.69685D-01
#
# At iterate  165    f= -1.68001D+02    |proj g|=  4.39376D-01
#
# At iterate  166    f= -1.68008D+02    |proj g|=  2.59623D-01
#
# At iterate  167    f= -1.68026D+02    |proj g|=  2.60894D-01
#
# At iterate  168    f= -1.68033D+02    |proj g|=  4.65184D-01
#
# At iterate  169    f= -1.68061D+02    |proj g|=  3.32142D-01
#
# At iterate  170    f= -1.68074D+02    |proj g|=  8.27706D-01
#
# At iterate  171    f= -1.68091D+02    |proj g|=  2.42756D-01
#
# At iterate  172    f= -1.68110D+02    |proj g|=  3.14007D-01
#
# At iterate  173    f= -1.68126D+02    |proj g|=  4.97034D-01
#
# At iterate  174    f= -1.68151D+02    |proj g|=  4.68118D-01
#
# At iterate  175    f= -1.68185D+02    |proj g|=  8.29643D-01
#
# At iterate  176    f= -1.68212D+02    |proj g|=  2.87242D-01
#
# At iterate  177    f= -1.68237D+02    |proj g|=  2.44922D-01
#
# At iterate  178    f= -1.68259D+02    |proj g|=  2.89191D-01
#
# At iterate  179    f= -1.68277D+02    |proj g|=  4.08587D-01
#
# At iterate  180    f= -1.68306D+02    |proj g|=  4.16217D-01
#
# At iterate  181    f= -1.68347D+02    |proj g|=  5.12325D-01
#
# At iterate  182    f= -1.68355D+02    |proj g|=  5.68341D-01
#
# At iterate  183    f= -1.68449D+02    |proj g|=  3.33334D-01
#
# At iterate  184    f= -1.68526D+02    |proj g|=  5.04888D-01
#
# At iterate  185    f= -1.68541D+02    |proj g|=  5.82846D-01
#
# At iterate  186    f= -1.68623D+02    |proj g|=  4.80350D-01
#
# At iterate  187    f= -1.68718D+02    |proj g|=  3.10458D-01
#
# At iterate  188    f= -1.68772D+02    |proj g|=  2.79506D-01
#
# At iterate  189    f= -1.68844D+02    |proj g|=  3.84541D-01
#
# At iterate  190    f= -1.68870D+02    |proj g|=  3.67538D-01
#
# At iterate  191    f= -1.68897D+02    |proj g|=  3.97738D-01
#
# At iterate  192    f= -1.68910D+02    |proj g|=  3.35731D-01
#
# At iterate  193    f= -1.68936D+02    |proj g|=  3.36854D-01
#
# At iterate  194    f= -1.68949D+02    |proj g|=  3.75784D-01
#
# At iterate  195    f= -1.68976D+02    |proj g|=  3.40121D-01
#
# At iterate  196    f= -1.68983D+02    |proj g|=  2.72281D-01
#
# At iterate  197    f= -1.69001D+02    |proj g|=  2.76720D-01
#
# At iterate  198    f= -1.69006D+02    |proj g|=  5.34724D-01
#
# At iterate  199    f= -1.69022D+02    |proj g|=  3.56625D-01
#
# At iterate  200    f= -1.69044D+02    |proj g|=  4.42411D-01
#
# At iterate  201    f= -1.69063D+02    |proj g|=  3.39620D-01
#
# At iterate  202    f= -1.69083D+02    |proj g|=  4.01566D-01
#
# At iterate  203    f= -1.69113D+02    |proj g|=  3.54871D-01
#
# At iterate  204    f= -1.69132D+02    |proj g|=  6.43352D-01
#
# At iterate  205    f= -1.69192D+02    |proj g|=  3.87795D-01
#
# At iterate  206    f= -1.69245D+02    |proj g|=  3.86017D-01
#
# At iterate  207    f= -1.69282D+02    |proj g|=  6.90386D-01
#
# At iterate  208    f= -1.69407D+02    |proj g|=  2.91346D-01
#
# At iterate  209    f= -1.69507D+02    |proj g|=  5.23832D-01
#
# At iterate  210    f= -1.69547D+02    |proj g|=  3.59399D-01
#
# At iterate  211    f= -1.69645D+02    |proj g|=  3.44890D-01
#
# At iterate  212    f= -1.69711D+02    |proj g|=  4.04099D-01
#
# At iterate  213    f= -1.69816D+02    |proj g|=  3.60077D-01
#
# At iterate  214    f= -1.69876D+02    |proj g|=  5.88954D-01
#
# At iterate  215    f= -1.69902D+02    |proj g|=  3.32814D-01
#
# At iterate  216    f= -1.69916D+02    |proj g|=  4.09358D-01
#
# At iterate  217    f= -1.69916D+02    |proj g|=  3.22062D-01
#
# At iterate  218    f= -1.69942D+02    |proj g|=  2.59350D-01
#
# At iterate  219    f= -1.69960D+02    |proj g|=  2.72678D-01
#
# At iterate  220    f= -1.69979D+02    |proj g|=  2.66686D-01
#
# At iterate  221    f= -1.69992D+02    |proj g|=  2.92394D-01
#
# At iterate  222    f= -1.70016D+02    |proj g|=  2.59381D-01
#
# At iterate  223    f= -1.70030D+02    |proj g|=  2.82605D-01
#
# At iterate  224    f= -1.70043D+02    |proj g|=  2.19799D-01
#
# At iterate  225    f= -1.70091D+02    |proj g|=  3.51972D-01
#
# At iterate  226    f= -1.70136D+02    |proj g|=  4.14785D-01
#
# At iterate  227    f= -1.70181D+02    |proj g|=  3.15803D-01
#
# At iterate  228    f= -1.70221D+02    |proj g|=  4.50587D-01
#
# At iterate  229    f= -1.70275D+02    |proj g|=  2.91460D-01
#
# At iterate  230    f= -1.70385D+02    |proj g|=  3.39424D-01
#
# At iterate  231    f= -1.70497D+02    |proj g|=  2.79777D-01
#
# At iterate  232    f= -1.70516D+02    |proj g|=  4.64893D-01
#
# At iterate  233    f= -1.70540D+02    |proj g|=  4.87452D-01
#
# At iterate  234    f= -1.70640D+02    |proj g|=  4.50862D-01
#
# At iterate  235    f= -1.70688D+02    |proj g|=  4.00107D-01
#
# At iterate  236    f= -1.70724D+02    |proj g|=  4.87473D-01
#
# At iterate  237    f= -1.70766D+02    |proj g|=  2.69284D-01
#
# At iterate  238    f= -1.70803D+02    |proj g|=  1.82338D-01
#
# At iterate  239    f= -1.70820D+02    |proj g|=  3.49578D-01
#
# At iterate  240    f= -1.70850D+02    |proj g|=  6.79151D-01
#
# At iterate  241    f= -1.70860D+02    |proj g|=  2.03343D-01
#
# At iterate  242    f= -1.70886D+02    |proj g|=  2.69793D-01
#
# At iterate  243    f= -1.70895D+02    |proj g|=  4.65101D-01
#
# At iterate  244    f= -1.70902D+02    |proj g|=  2.48568D-01
#
# At iterate  245    f= -1.70917D+02    |proj g|=  2.40121D-01
#
# At iterate  246    f= -1.70951D+02    |proj g|=  3.13557D-01
#
# At iterate  247    f= -1.70964D+02    |proj g|=  3.91610D-01
#
# At iterate  248    f= -1.70979D+02    |proj g|=  2.95354D-01
#
# At iterate  249    f= -1.71011D+02    |proj g|=  2.76966D-01
#
# At iterate  250    f= -1.71038D+02    |proj g|=  5.16984D-01
#
# At iterate  251    f= -1.71062D+02    |proj g|=  2.82934D-01
#
# At iterate  252    f= -1.71099D+02    |proj g|=  2.93465D-01
#
# At iterate  253    f= -1.71128D+02    |proj g|=  4.06317D-01
#
# At iterate  254    f= -1.71158D+02    |proj g|=  3.96116D-01
#
# At iterate  255    f= -1.71182D+02    |proj g|=  2.73145D-01
#
# At iterate  256    f= -1.71198D+02    |proj g|=  4.41486D-01
#
# At iterate  257    f= -1.71215D+02    |proj g|=  2.41511D-01
#
# At iterate  258    f= -1.71215D+02    |proj g|=  2.57425D-01
#
# At iterate  259    f= -1.71230D+02    |proj g|=  2.27518D-01
#
# At iterate  260    f= -1.71254D+02    |proj g|=  3.89543D-01
#
# At iterate  261    f= -1.71267D+02    |proj g|=  7.58831D-01
#
# At iterate  262    f= -1.71280D+02    |proj g|=  1.96334D-01
#
# At iterate  263    f= -1.71285D+02    |proj g|=  2.12543D-01
#
# At iterate  264    f= -1.71292D+02    |proj g|=  2.12017D-01
#
# At iterate  265    f= -1.71298D+02    |proj g|=  3.19466D-01
#
# At iterate  266    f= -1.71309D+02    |proj g|=  1.72263D-01
#
# At iterate  267    f= -1.71317D+02    |proj g|=  4.07967D-01
#
# At iterate  268    f= -1.71333D+02    |proj g|=  2.61798D-01
#
# At iterate  269    f= -1.71348D+02    |proj g|=  2.19423D-01
#
# At iterate  270    f= -1.71354D+02    |proj g|=  3.48176D-01
#
# At iterate  271    f= -1.71377D+02    |proj g|=  3.16038D-01
#
# At iterate  272    f= -1.71400D+02    |proj g|=  3.63861D-01
#
# At iterate  273    f= -1.71414D+02    |proj g|=  2.65314D-01
#
# At iterate  274    f= -1.71428D+02    |proj g|=  3.54253D-01
#
# At iterate  275    f= -1.71444D+02    |proj g|=  1.77634D-01
#
# At iterate  276    f= -1.71457D+02    |proj g|=  2.41251D-01
#
# At iterate  277    f= -1.71464D+02    |proj g|=  3.37925D-01
#
# At iterate  278    f= -1.71473D+02    |proj g|=  2.52774D-01
#
# At iterate  279    f= -1.71491D+02    |proj g|=  2.21351D-01
#
# At iterate  280    f= -1.71509D+02    |proj g|=  2.21414D-01
#
# At iterate  281    f= -1.71520D+02    |proj g|=  3.05360D-01
#
# At iterate  282    f= -1.71526D+02    |proj g|=  3.81731D-01
#
# At iterate  283    f= -1.71548D+02    |proj g|=  2.96879D-01
#
# At iterate  284    f= -1.71582D+02    |proj g|=  2.56534D-01
#
# At iterate  285    f= -1.71609D+02    |proj g|=  3.81471D-01
#
# At iterate  286    f= -1.71623D+02    |proj g|=  6.02605D-01
#
# At iterate  287    f= -1.71673D+02    |proj g|=  3.54212D-01
#
# At iterate  288    f= -1.71694D+02    |proj g|=  2.99974D-01
#
# At iterate  289    f= -1.71710D+02    |proj g|=  8.90081D-01
#
# At iterate  290    f= -1.71740D+02    |proj g|=  4.41656D-01
#
# At iterate  291    f= -1.71775D+02    |proj g|=  3.18991D-01
#
# At iterate  292    f= -1.71802D+02    |proj g|=  3.67342D-01
#
# At iterate  293    f= -1.71809D+02    |proj g|=  3.21497D-01
#
# At iterate  294    f= -1.71829D+02    |proj g|=  3.77143D-01
#
# At iterate  295    f= -1.71841D+02    |proj g|=  2.07386D-01
#
# At iterate  296    f= -1.71855D+02    |proj g|=  2.13974D-01
#
# At iterate  297    f= -1.71864D+02    |proj g|=  2.35803D-01
#
# At iterate  298    f= -1.71877D+02    |proj g|=  2.17184D-01
#
# At iterate  299    f= -1.71888D+02    |proj g|=  2.42061D-01
#
# At iterate  300    f= -1.71901D+02    |proj g|=  3.24376D-01
#
# At iterate  301    f= -1.71910D+02    |proj g|=  3.98472D-01
#
# At iterate  302    f= -1.71930D+02    |proj g|=  1.82934D-01
#
# At iterate  303    f= -1.71945D+02    |proj g|=  4.60135D-01
#
# At iterate  304    f= -1.71967D+02    |proj g|=  2.34623D-01
#
# At iterate  305    f= -1.71979D+02    |proj g|=  2.46154D-01
#
# At iterate  306    f= -1.71993D+02    |proj g|=  3.58208D-01
#
# At iterate  307    f= -1.72005D+02    |proj g|=  2.95437D-01
#
# At iterate  308    f= -1.72021D+02    |proj g|=  3.15615D-01
#
# At iterate  309    f= -1.72029D+02    |proj g|=  2.23433D-01
#
# At iterate  310    f= -1.72044D+02    |proj g|=  3.03356D-01
#
# At iterate  311    f= -1.72057D+02    |proj g|=  2.27931D-01
#
# At iterate  312    f= -1.72063D+02    |proj g|=  3.26780D-01
#
# At iterate  313    f= -1.72084D+02    |proj g|=  2.53277D-01
#
# At iterate  314    f= -1.72096D+02    |proj g|=  2.71445D-01
#
# At iterate  315    f= -1.72104D+02    |proj g|=  2.47434D-01
#
# At iterate  316    f= -1.72112D+02    |proj g|=  4.13344D-01
#
# At iterate  317    f= -1.72129D+02    |proj g|=  5.75777D-01
#
# At iterate  318    f= -1.72149D+02    |proj g|=  2.66200D-01
#
# At iterate  319    f= -1.72164D+02    |proj g|=  4.10301D-01
#
# At iterate  320    f= -1.72185D+02    |proj g|=  5.78638D-01
#
# At iterate  321    f= -1.72205D+02    |proj g|=  4.60664D-01
#
# At iterate  322    f= -1.72226D+02    |proj g|=  4.54048D-01
#
# At iterate  323    f= -1.72248D+02    |proj g|=  2.79325D-01
#
# At iterate  324    f= -1.72266D+02    |proj g|=  2.20371D-01
#
# At iterate  325    f= -1.72277D+02    |proj g|=  5.46088D-01
#
# At iterate  326    f= -1.72298D+02    |proj g|=  2.69094D-01
#
# At iterate  327    f= -1.72328D+02    |proj g|=  2.74987D-01
#
# At iterate  328    f= -1.72352D+02    |proj g|=  4.36005D-01
#
# At iterate  329    f= -1.72365D+02    |proj g|=  4.00194D-01
#
# At iterate  330    f= -1.72380D+02    |proj g|=  4.75940D-01
#
# At iterate  331    f= -1.72397D+02    |proj g|=  2.00273D-01
#
# At iterate  332    f= -1.72405D+02    |proj g|=  2.43506D-01
#
# At iterate  333    f= -1.72419D+02    |proj g|=  3.57351D-01
#
# At iterate  334    f= -1.72433D+02    |proj g|=  2.74481D-01
#
# At iterate  335    f= -1.72451D+02    |proj g|=  5.09959D-01
#
# At iterate  336    f= -1.72471D+02    |proj g|=  3.86022D-01
#
# At iterate  337    f= -1.72482D+02    |proj g|=  2.87660D-01
#
# At iterate  338    f= -1.72503D+02    |proj g|=  2.15406D-01
#
# At iterate  339    f= -1.72519D+02    |proj g|=  2.70024D-01
#
# At iterate  340    f= -1.72532D+02    |proj g|=  3.14881D-01
#
# At iterate  341    f= -1.72558D+02    |proj g|=  2.87920D-01
#
# At iterate  342    f= -1.72569D+02    |proj g|=  2.51562D-01
#
# At iterate  343    f= -1.72579D+02    |proj g|=  3.05868D-01
#
# At iterate  344    f= -1.72608D+02    |proj g|=  3.59351D-01
#
# At iterate  345    f= -1.72626D+02    |proj g|=  4.89648D-01
#
# At iterate  346    f= -1.72658D+02    |proj g|=  2.37745D-01
#
# At iterate  347    f= -1.72680D+02    |proj g|=  2.59951D-01
#
# At iterate  348    f= -1.72693D+02    |proj g|=  5.56443D-01
#
# At iterate  349    f= -1.72713D+02    |proj g|=  2.71881D-01
#
# At iterate  350    f= -1.72713D+02    |proj g|=  3.44463D-01
#
# At iterate  351    f= -1.72732D+02    |proj g|=  4.28040D-01
#
# At iterate  352    f= -1.72744D+02    |proj g|=  2.87860D-01
#
# At iterate  353    f= -1.72746D+02    |proj g|=  3.03726D-01
#
# At iterate  354    f= -1.72750D+02    |proj g|=  5.62580D-01
#
# At iterate  355    f= -1.72759D+02    |proj g|=  3.86670D-01
#
# At iterate  356    f= -1.72772D+02    |proj g|=  5.46236D-01
#
# At iterate  357    f= -1.72773D+02    |proj g|=  2.07986D-01
#
# At iterate  358    f= -1.72786D+02    |proj g|=  2.70117D-01
#
# At iterate  359    f= -1.72799D+02    |proj g|=  6.41091D-01
#
# At iterate  360    f= -1.72805D+02    |proj g|=  2.83664D-01
#
# At iterate  361    f= -1.72821D+02    |proj g|=  4.25987D-01
#
# At iterate  362    f= -1.72841D+02    |proj g|=  3.83345D-01
#
# At iterate  363    f= -1.72853D+02    |proj g|=  2.71276D-01
#
# At iterate  364    f= -1.72868D+02    |proj g|=  4.04355D-01
#
# At iterate  365    f= -1.72893D+02    |proj g|=  3.45220D-01
#
# At iterate  366    f= -1.72921D+02    |proj g|=  5.30252D-01
#
# At iterate  367    f= -1.72941D+02    |proj g|=  5.92100D-01
#
# At iterate  368    f= -1.72983D+02    |proj g|=  3.01814D-01
#
# At iterate  369    f= -1.73000D+02    |proj g|=  4.40142D-01
#
# At iterate  370    f= -1.73028D+02    |proj g|=  4.10867D-01
#
# At iterate  371    f= -1.73054D+02    |proj g|=  4.20182D-01
#
# At iterate  372    f= -1.73078D+02    |proj g|=  3.72167D-01
#
# At iterate  373    f= -1.73104D+02    |proj g|=  3.03208D-01
#
# At iterate  374    f= -1.73132D+02    |proj g|=  5.16677D-01
#
# At iterate  375    f= -1.73146D+02    |proj g|=  3.59966D-01
#
# At iterate  376    f= -1.73164D+02    |proj g|=  2.67936D-01
#
# At iterate  377    f= -1.73181D+02    |proj g|=  3.84730D-01
#
# At iterate  378    f= -1.73188D+02    |proj g|=  2.51527D-01
#
# At iterate  379    f= -1.73196D+02    |proj g|=  2.46108D-01
#
# At iterate  380    f= -1.73212D+02    |proj g|=  4.39855D-01
#
# At iterate  381    f= -1.73232D+02    |proj g|=  4.77310D-01
#
# At iterate  382    f= -1.73247D+02    |proj g|=  3.09150D-01
#
# At iterate  383    f= -1.73261D+02    |proj g|=  2.10548D-01
#
# At iterate  384    f= -1.73280D+02    |proj g|=  4.26678D-01
#
# At iterate  385    f= -1.73283D+02    |proj g|=  4.92890D-01
#
# At iterate  386    f= -1.73298D+02    |proj g|=  2.77852D-01
#
# At iterate  387    f= -1.73303D+02    |proj g|=  3.68940D-01
#
# At iterate  388    f= -1.73317D+02    |proj g|=  4.20976D-01
#
# At iterate  389    f= -1.73327D+02    |proj g|=  2.28517D-01
#
# At iterate  390    f= -1.73333D+02    |proj g|=  4.63440D-01
#
# At iterate  391    f= -1.73338D+02    |proj g|=  2.80938D-01
#
# At iterate  392    f= -1.73340D+02    |proj g|=  3.83600D-01
#
# At iterate  393    f= -1.73347D+02    |proj g|=  1.67439D-01
#
# At iterate  394    f= -1.73350D+02    |proj g|=  2.75381D-01
#
# At iterate  395    f= -1.73356D+02    |proj g|=  1.96667D-01
#
# At iterate  396    f= -1.73363D+02    |proj g|=  2.95061D-01
#
# At iterate  397    f= -1.73376D+02    |proj g|=  2.23387D-01
#
# At iterate  398    f= -1.73400D+02    |proj g|=  1.70556D-01
#
# At iterate  399    f= -1.73426D+02    |proj g|=  2.91470D-01
#
# At iterate  400    f= -1.73459D+02    |proj g|=  3.47876D-01
#
# At iterate  401    f= -1.73497D+02    |proj g|=  4.17631D-01
#
# At iterate  402    f= -1.73548D+02    |proj g|=  3.37212D-01
#
# At iterate  403    f= -1.73582D+02    |proj g|=  3.80534D-01
#
# At iterate  404    f= -1.73633D+02    |proj g|=  4.61726D-01
#
# At iterate  405    f= -1.73698D+02    |proj g|=  3.59084D-01
#
# At iterate  406    f= -1.73737D+02    |proj g|=  3.10239D-01
#
# At iterate  407    f= -1.73752D+02    |proj g|=  3.15217D-01
#
# At iterate  408    f= -1.73784D+02    |proj g|=  3.00372D-01
#
# At iterate  409    f= -1.73799D+02    |proj g|=  5.28099D-01
#
# At iterate  410    f= -1.73846D+02    |proj g|=  1.99521D-01
#
# At iterate  411    f= -1.73876D+02    |proj g|=  2.69089D-01
#
# At iterate  412    f= -1.73893D+02    |proj g|=  3.47615D-01
#
# At iterate  413    f= -1.73897D+02    |proj g|=  3.54225D-01
#
# At iterate  414    f= -1.73904D+02    |proj g|=  6.02009D-01
#
# At iterate  415    f= -1.73911D+02    |proj g|=  5.47302D-01
#
# At iterate  416    f= -1.73916D+02    |proj g|=  6.77690D-01
#
# At iterate  417    f= -1.73966D+02    |proj g|=  5.42887D-01
#
# At iterate  418    f= -1.73999D+02    |proj g|=  2.66157D-01
#
# At iterate  419    f= -1.74025D+02    |proj g|=  2.33564D-01
#
# At iterate  420    f= -1.74066D+02    |proj g|=  4.60899D-01
#
# At iterate  421    f= -1.74108D+02    |proj g|=  6.57498D-01
#
# At iterate  422    f= -1.74112D+02    |proj g|=  4.55136D-01
#
# At iterate  423    f= -1.74176D+02    |proj g|=  4.38058D-01
#
# At iterate  424    f= -1.74283D+02    |proj g|=  4.84459D-01
#
# At iterate  425    f= -1.74359D+02    |proj g|=  4.79485D-01
#
# At iterate  426    f= -1.74421D+02    |proj g|=  3.42697D-01
#
# At iterate  427    f= -1.74461D+02    |proj g|=  4.63819D-01
#
# At iterate  428    f= -1.74607D+02    |proj g|=  6.24821D-01
#
# At iterate  429    f= -1.74635D+02    |proj g|=  3.96704D-01
#
# At iterate  430    f= -1.74750D+02    |proj g|=  5.98126D-01
#
# At iterate  431    f= -1.74780D+02    |proj g|=  4.54810D-01
#
# At iterate  432    f= -1.74841D+02    |proj g|=  2.96561D-01
#
# At iterate  433    f= -1.74878D+02    |proj g|=  2.33490D-01
#
# At iterate  434    f= -1.74895D+02    |proj g|=  4.51723D-01
#
# At iterate  435    f= -1.74904D+02    |proj g|=  3.02984D-01
#
# At iterate  436    f= -1.74944D+02    |proj g|=  6.67142D-01
#
# At iterate  437    f= -1.74954D+02    |proj g|=  4.18965D-01
#
# At iterate  438    f= -1.74967D+02    |proj g|=  3.44309D-01
#
# At iterate  439    f= -1.74978D+02    |proj g|=  3.17213D-01
#
# At iterate  440    f= -1.74994D+02    |proj g|=  2.48140D-01
#
# At iterate  441    f= -1.75006D+02    |proj g|=  4.98351D-01
#
# At iterate  442    f= -1.75024D+02    |proj g|=  3.21609D-01
#
# At iterate  443    f= -1.75029D+02    |proj g|=  4.51265D-01
#
# At iterate  444    f= -1.75041D+02    |proj g|=  2.34029D-01
#
# At iterate  445    f= -1.75050D+02    |proj g|=  3.14892D-01
#
# At iterate  446    f= -1.75064D+02    |proj g|=  3.04208D-01
#
# At iterate  447    f= -1.75078D+02    |proj g|=  2.44829D-01
#
# At iterate  448    f= -1.75086D+02    |proj g|=  3.15414D-01
#
# At iterate  449    f= -1.75104D+02    |proj g|=  5.34738D-01
#
# At iterate  450    f= -1.75124D+02    |proj g|=  3.59865D-01
#
# At iterate  451    f= -1.75141D+02    |proj g|=  2.91848D-01
#
# At iterate  452    f= -1.75164D+02    |proj g|=  4.77076D-01
#
# At iterate  453    f= -1.75184D+02    |proj g|=  4.16103D-01
#
# At iterate  454    f= -1.75216D+02    |proj g|=  5.17764D-01
#
# At iterate  455    f= -1.75274D+02    |proj g|=  3.32774D-01
#
# At iterate  456    f= -1.75305D+02    |proj g|=  3.26881D-01
#
# At iterate  457    f= -1.75341D+02    |proj g|=  3.83658D-01
#
# At iterate  458    f= -1.75397D+02    |proj g|=  3.44356D-01
#
# At iterate  459    f= -1.75439D+02    |proj g|=  3.67578D-01
#
# At iterate  460    f= -1.75501D+02    |proj g|=  2.49538D-01
#
# At iterate  461    f= -1.75501D+02    |proj g|=  5.08564D-01
#
# At iterate  462    f= -1.75595D+02    |proj g|=  4.14054D-01
#
# At iterate  463    f= -1.75630D+02    |proj g|=  3.38179D-01
#
# At iterate  464    f= -1.75655D+02    |proj g|=  3.01176D-01
#
# At iterate  465    f= -1.75661D+02    |proj g|=  3.58407D-01
#
# At iterate  466    f= -1.75680D+02    |proj g|=  3.64982D-01
#
# At iterate  467    f= -1.75688D+02    |proj g|=  4.18061D-01
#
# At iterate  468    f= -1.75720D+02    |proj g|=  4.79247D-01
#
# At iterate  469    f= -1.75735D+02    |proj g|=  3.16179D-01
#
# At iterate  470    f= -1.75759D+02    |proj g|=  5.35863D-01
#
# At iterate  471    f= -1.75776D+02    |proj g|=  1.93561D-01
#
# At iterate  472    f= -1.75791D+02    |proj g|=  3.75217D-01
#
# At iterate  473    f= -1.75802D+02    |proj g|=  6.12145D-01
#
# At iterate  474    f= -1.75817D+02    |proj g|=  2.50115D-01
#
# At iterate  475    f= -1.75825D+02    |proj g|=  2.64589D-01
#
# At iterate  476    f= -1.75830D+02    |proj g|=  3.68963D-01
#
# At iterate  477    f= -1.75855D+02    |proj g|=  3.96161D-01
#
# At iterate  478    f= -1.75870D+02    |proj g|=  3.20685D-01
#
# At iterate  479    f= -1.75886D+02    |proj g|=  3.40704D-01
#
# At iterate  480    f= -1.75911D+02    |proj g|=  2.68216D-01
#
# At iterate  481    f= -1.75940D+02    |proj g|=  5.12599D-01
#
# At iterate  482    f= -1.75976D+02    |proj g|=  4.15316D-01
#
# At iterate  483    f= -1.76004D+02    |proj g|=  3.77729D-01
#
# At iterate  484    f= -1.76052D+02    |proj g|=  2.99576D-01
#
# At iterate  485    f= -1.76097D+02    |proj g|=  3.72075D-01
#
# At iterate  486    f= -1.76125D+02    |proj g|=  4.09507D-01
#
# At iterate  487    f= -1.76163D+02    |proj g|=  5.58762D-01
#
# At iterate  488    f= -1.76205D+02    |proj g|=  5.30921D-01
#
# At iterate  489    f= -1.76223D+02    |proj g|=  3.41559D-01
#
# At iterate  490    f= -1.76258D+02    |proj g|=  5.52574D-01
#
# At iterate  491    f= -1.76273D+02    |proj g|=  3.22162D-01
#
# At iterate  492    f= -1.76275D+02    |proj g|=  5.24864D-01
#
# At iterate  493    f= -1.76322D+02    |proj g|=  1.66904D-01
#
# At iterate  494    f= -1.76325D+02    |proj g|=  4.50689D-01
#
# At iterate  495    f= -1.76330D+02    |proj g|=  3.53410D-01
#
# At iterate  496    f= -1.76352D+02    |proj g|=  2.90681D-01
#
# At iterate  497    f= -1.76369D+02    |proj g|=  6.75297D-01
#
# At iterate  498    f= -1.76372D+02    |proj g|=  7.12730D-01
#
# At iterate  499    f= -1.76389D+02    |proj g|=  3.02297D-01
#
# At iterate  500    f= -1.76398D+02    |proj g|=  2.53699D-01
#
# At iterate  501    f= -1.76406D+02    |proj g|=  2.71164D-01
#
# At iterate  502    f= -1.76416D+02    |proj g|=  2.65273D-01
#
# At iterate  503    f= -1.76421D+02    |proj g|=  7.54760D-01
#
# At iterate  504    f= -1.76435D+02    |proj g|=  3.43945D-01
#
# At iterate  505    f= -1.76450D+02    |proj g|=  3.39530D-01
#
# At iterate  506    f= -1.76466D+02    |proj g|=  3.21438D-01
#
# At iterate  507    f= -1.76509D+02    |proj g|=  3.62251D-01
#
# At iterate  508    f= -1.76557D+02    |proj g|=  4.15900D-01
#
# At iterate  509    f= -1.76588D+02    |proj g|=  3.73171D-01
#
# At iterate  510    f= -1.76655D+02    |proj g|=  3.87507D-01
#
# At iterate  511    f= -1.76722D+02    |proj g|=  4.23362D-01
#
# At iterate  512    f= -1.76774D+02    |proj g|=  5.14224D-01
#
# At iterate  513    f= -1.76848D+02    |proj g|=  5.98163D-01
#
# At iterate  514    f= -1.76879D+02    |proj g|=  3.94615D-01
#
# At iterate  515    f= -1.76894D+02    |proj g|=  4.41847D-01
#
# At iterate  516    f= -1.76916D+02    |proj g|=  6.96068D-01
#
# At iterate  517    f= -1.76936D+02    |proj g|=  3.22187D-01
#
# At iterate  518    f= -1.76954D+02    |proj g|=  4.04868D-01
#
# At iterate  519    f= -1.76994D+02    |proj g|=  4.03773D-01
#
# At iterate  520    f= -1.77007D+02    |proj g|=  3.13753D-01
#
# At iterate  521    f= -1.77017D+02    |proj g|=  3.62933D-01
#
# At iterate  522    f= -1.77026D+02    |proj g|=  3.77261D-01
#
# At iterate  523    f= -1.77039D+02    |proj g|=  3.39840D-01
#
# At iterate  524    f= -1.77041D+02    |proj g|=  3.07145D-01
#
# At iterate  525    f= -1.77054D+02    |proj g|=  2.82267D-01
#
# At iterate  526    f= -1.77063D+02    |proj g|=  3.59119D-01
#
# At iterate  527    f= -1.77065D+02    |proj g|=  4.41768D-01
#
# At iterate  528    f= -1.77076D+02    |proj g|=  2.60925D-01
#
# At iterate  529    f= -1.77082D+02    |proj g|=  3.02347D-01
#
# At iterate  530    f= -1.77085D+02    |proj g|=  3.42586D-01
#
# At iterate  531    f= -1.77095D+02    |proj g|=  2.21249D-01
#
# At iterate  532    f= -1.77102D+02    |proj g|=  2.49415D-01
#
# At iterate  533    f= -1.77108D+02    |proj g|=  4.66939D-01
#
# At iterate  534    f= -1.77117D+02    |proj g|=  2.23811D-01
#
# At iterate  535    f= -1.77124D+02    |proj g|=  3.88258D-01
#
# At iterate  536    f= -1.77140D+02    |proj g|=  3.50309D-01
#
# At iterate  537    f= -1.77162D+02    |proj g|=  3.41445D-01
#
# At iterate  538    f= -1.77213D+02    |proj g|=  4.69506D-01
#
# At iterate  539    f= -1.77290D+02    |proj g|=  5.89739D-01
#
# At iterate  540    f= -1.77362D+02    |proj g|=  4.65062D-01
#
# At iterate  541    f= -1.77437D+02    |proj g|=  3.84846D-01
#
# At iterate  542    f= -1.77444D+02    |proj g|=  5.02038D-01
#
# At iterate  543    f= -1.77499D+02    |proj g|=  5.20334D-01
#
# At iterate  544    f= -1.77541D+02    |proj g|=  2.96929D-01
#
# At iterate  545    f= -1.77551D+02    |proj g|=  4.05261D-01
#
# At iterate  546    f= -1.77559D+02    |proj g|=  4.85229D-01
#
# At iterate  547    f= -1.77594D+02    |proj g|=  3.40665D-01
#
# At iterate  548    f= -1.77601D+02    |proj g|=  3.69897D-01
#
# At iterate  549    f= -1.77628D+02    |proj g|=  3.32316D-01
#
# At iterate  550    f= -1.77645D+02    |proj g|=  2.69771D-01
#
# At iterate  551    f= -1.77653D+02    |proj g|=  3.38008D-01
#
# At iterate  552    f= -1.77665D+02    |proj g|=  5.77427D-01
#
# At iterate  553    f= -1.77682D+02    |proj g|=  3.63787D-01
#
# At iterate  554    f= -1.77686D+02    |proj g|=  4.88933D-01
#
# At iterate  555    f= -1.77700D+02    |proj g|=  3.01596D-01
#
# At iterate  556    f= -1.77710D+02    |proj g|=  4.19666D-01
#
# At iterate  557    f= -1.77724D+02    |proj g|=  3.42376D-01
#
# At iterate  558    f= -1.77742D+02    |proj g|=  2.76765D-01
#
# At iterate  559    f= -1.77757D+02    |proj g|=  2.37377D-01
#
# At iterate  560    f= -1.77784D+02    |proj g|=  4.16032D-01
#
# At iterate  561    f= -1.77810D+02    |proj g|=  4.18887D-01
#
# At iterate  562    f= -1.77845D+02    |proj g|=  5.47760D-01
#
# At iterate  563    f= -1.77875D+02    |proj g|=  4.13723D-01
#
# At iterate  564    f= -1.77906D+02    |proj g|=  4.43567D-01
#
# At iterate  565    f= -1.77957D+02    |proj g|=  4.98595D-01
#
# At iterate  566    f= -1.78007D+02    |proj g|=  4.59200D-01
#
# At iterate  567    f= -1.78073D+02    |proj g|=  3.69852D-01
#
# At iterate  568    f= -1.78093D+02    |proj g|=  5.02141D-01
#
# At iterate  569    f= -1.78123D+02    |proj g|=  3.91321D-01
#
# At iterate  570    f= -1.78160D+02    |proj g|=  4.02226D-01
#
# At iterate  571    f= -1.78201D+02    |proj g|=  7.49709D-01
#
# At iterate  572    f= -1.78231D+02    |proj g|=  4.17905D-01
#
# At iterate  573    f= -1.78268D+02    |proj g|=  4.21720D-01
#
# At iterate  574    f= -1.78313D+02    |proj g|=  3.79749D-01
#
# At iterate  575    f= -1.78365D+02    |proj g|=  5.10763D-01
#
# At iterate  576    f= -1.78446D+02    |proj g|=  4.00852D-01
#
# At iterate  577    f= -1.78487D+02    |proj g|=  3.90496D-01
#
# At iterate  578    f= -1.78507D+02    |proj g|=  2.16512D-01
#
# At iterate  579    f= -1.78533D+02    |proj g|=  4.26083D-01
#
# At iterate  580    f= -1.78542D+02    |proj g|=  4.36463D-01
#
# At iterate  581    f= -1.78562D+02    |proj g|=  3.48934D-01
#
# At iterate  582    f= -1.78592D+02    |proj g|=  3.59580D-01
#
# At iterate  583    f= -1.78619D+02    |proj g|=  4.94672D-01
#
# At iterate  584    f= -1.78624D+02    |proj g|=  3.45546D-01
#
# At iterate  585    f= -1.78645D+02    |proj g|=  5.91550D-01
#
# At iterate  586    f= -1.78649D+02    |proj g|=  4.27551D-01
#
# At iterate  587    f= -1.78675D+02    |proj g|=  3.05977D-01
#
# At iterate  588    f= -1.78686D+02    |proj g|=  4.19592D-01
#
# At iterate  589    f= -1.78706D+02    |proj g|=  3.79193D-01
#
# At iterate  590    f= -1.78722D+02    |proj g|=  4.29403D-01
#
# At iterate  591    f= -1.78755D+02    |proj g|=  2.96330D-01
#
# At iterate  592    f= -1.78766D+02    |proj g|=  7.12360D-01
#
# At iterate  593    f= -1.78790D+02    |proj g|=  4.45006D-01
#
# At iterate  594    f= -1.78791D+02    |proj g|=  9.90608D-01
#
# At iterate  595    f= -1.78804D+02    |proj g|=  7.04746D-01
#
# At iterate  596    f= -1.78830D+02    |proj g|=  4.67967D-01
#
# At iterate  597    f= -1.78855D+02    |proj g|=  3.87622D-01
#
# At iterate  598    f= -1.78892D+02    |proj g|=  6.02798D-01
#
# At iterate  599    f= -1.78932D+02    |proj g|=  3.34874D-01
#
# At iterate  600    f= -1.78978D+02    |proj g|=  4.45231D-01
#
# At iterate  601    f= -1.79056D+02    |proj g|=  5.37956D-01
#
# At iterate  602    f= -1.79169D+02    |proj g|=  3.63752D-01
#
# At iterate  603    f= -1.79245D+02    |proj g|=  5.15005D-01
#
# At iterate  604    f= -1.79280D+02    |proj g|=  6.23354D-01
#
# At iterate  605    f= -1.79354D+02    |proj g|=  5.83136D-01
#
# At iterate  606    f= -1.79380D+02    |proj g|=  5.05156D-01
#
# At iterate  607    f= -1.79435D+02    |proj g|=  5.50066D-01
#
# At iterate  608    f= -1.79497D+02    |proj g|=  3.68451D-01
#
# At iterate  609    f= -1.79537D+02    |proj g|=  3.40518D-01
#
# At iterate  610    f= -1.79594D+02    |proj g|=  3.78305D-01
#
# At iterate  611    f= -1.79627D+02    |proj g|=  4.02538D-01
#
# At iterate  612    f= -1.79659D+02    |proj g|=  4.94775D-01
#
# At iterate  613    f= -1.79690D+02    |proj g|=  4.70124D-01
#
# At iterate  614    f= -1.79710D+02    |proj g|=  4.61012D-01
#
# At iterate  615    f= -1.79735D+02    |proj g|=  5.13835D-01
#
# At iterate  616    f= -1.79739D+02    |proj g|=  6.72111D-01
#
# At iterate  617    f= -1.79779D+02    |proj g|=  4.17677D-01
#
# At iterate  618    f= -1.79802D+02    |proj g|=  6.05907D-01
#
# At iterate  619    f= -1.79811D+02    |proj g|=  3.67002D-01
#
# At iterate  620    f= -1.79846D+02    |proj g|=  4.26137D-01
#
# At iterate  621    f= -1.79870D+02    |proj g|=  4.87855D-01
#
# At iterate  622    f= -1.79898D+02    |proj g|=  3.41992D-01
#
# At iterate  623    f= -1.79909D+02    |proj g|=  3.45454D-01
#
# At iterate  624    f= -1.79911D+02    |proj g|=  3.68093D-01
#
# At iterate  625    f= -1.79937D+02    |proj g|=  5.27419D-01
#
# At iterate  626    f= -1.79945D+02    |proj g|=  5.72615D-01
#
# At iterate  627    f= -1.79958D+02    |proj g|=  4.45086D-01
#
# At iterate  628    f= -1.79972D+02    |proj g|=  5.47565D-01
#
# At iterate  629    f= -1.79984D+02    |proj g|=  3.35860D-01
#
# At iterate  630    f= -1.79997D+02    |proj g|=  2.22202D-01
#
# At iterate  631    f= -1.80011D+02    |proj g|=  4.60428D-01
#
# At iterate  632    f= -1.80028D+02    |proj g|=  3.67119D-01
#
# At iterate  633    f= -1.80043D+02    |proj g|=  3.07379D-01
#
# At iterate  634    f= -1.80045D+02    |proj g|=  5.79963D-01
#
# At iterate  635    f= -1.80075D+02    |proj g|=  4.17010D-01
#
# At iterate  636    f= -1.80087D+02    |proj g|=  4.56162D-01
#
# At iterate  637    f= -1.80091D+02    |proj g|=  3.31753D-01
#
# At iterate  638    f= -1.80111D+02    |proj g|=  5.52158D-01
#
# At iterate  639    f= -1.80146D+02    |proj g|=  5.10173D-01
#
# At iterate  640    f= -1.80156D+02    |proj g|=  3.38380D-01
#
# At iterate  641    f= -1.80170D+02    |proj g|=  3.65011D-01
#
# At iterate  642    f= -1.80178D+02    |proj g|=  4.64745D-01
#
# At iterate  643    f= -1.80184D+02    |proj g|=  5.55942D-01
#
# At iterate  644    f= -1.80209D+02    |proj g|=  4.51357D-01
#
# At iterate  645    f= -1.80224D+02    |proj g|=  5.94263D-01
#
# At iterate  646    f= -1.80242D+02    |proj g|=  5.80492D-01
#
# At iterate  647    f= -1.80275D+02    |proj g|=  3.69182D-01
#
# At iterate  648    f= -1.80287D+02    |proj g|=  3.38661D-01
#
# At iterate  649    f= -1.80292D+02    |proj g|=  4.08828D-01
#
# At iterate  650    f= -1.80309D+02    |proj g|=  4.17407D-01
#
# At iterate  651    f= -1.80319D+02    |proj g|=  4.19980D-01
#
# At iterate  652    f= -1.80340D+02    |proj g|=  5.67417D-01
#
# At iterate  653    f= -1.80352D+02    |proj g|=  4.40790D-01
#
# At iterate  654    f= -1.80366D+02    |proj g|=  3.71024D-01
#
# At iterate  655    f= -1.80374D+02    |proj g|=  3.13601D-01
#
# At iterate  656    f= -1.80383D+02    |proj g|=  3.60044D-01
#
# At iterate  657    f= -1.80402D+02    |proj g|=  5.90280D-01
#
# At iterate  658    f= -1.80415D+02    |proj g|=  3.92521D-01
#
# At iterate  659    f= -1.80424D+02    |proj g|=  5.06407D-01
#
# At iterate  660    f= -1.80434D+02    |proj g|=  3.83947D-01
#
# At iterate  661    f= -1.80454D+02    |proj g|=  2.93427D-01
#
# At iterate  662    f= -1.80474D+02    |proj g|=  4.74382D-01
#
# At iterate  663    f= -1.80481D+02    |proj g|=  4.47796D-01
#
# At iterate  664    f= -1.80495D+02    |proj g|=  7.50824D-01
#
# At iterate  665    f= -1.80497D+02    |proj g|=  3.77033D-01
#
# At iterate  666    f= -1.80514D+02    |proj g|=  5.87571D-01
#
# At iterate  667    f= -1.80525D+02    |proj g|=  3.36142D-01
#
# At iterate  668    f= -1.80539D+02    |proj g|=  2.76278D-01
#
# At iterate  669    f= -1.80555D+02    |proj g|=  3.45776D-01
#
# At iterate  670    f= -1.80563D+02    |proj g|=  4.08454D-01
#
# At iterate  671    f= -1.80564D+02    |proj g|=  3.43424D-01
#
# At iterate  672    f= -1.80587D+02    |proj g|=  3.83575D-01
#
# At iterate  673    f= -1.80607D+02    |proj g|=  3.62776D-01
#
# At iterate  674    f= -1.80608D+02    |proj g|=  5.02590D-01
#
# At iterate  675    f= -1.80635D+02    |proj g|=  3.78566D-01
#
# At iterate  676    f= -1.80652D+02    |proj g|=  3.60970D-01
#
# At iterate  677    f= -1.80657D+02    |proj g|=  3.73420D-01
#
# At iterate  678    f= -1.80666D+02    |proj g|=  4.45550D-01
#
# At iterate  679    f= -1.80670D+02    |proj g|=  4.97907D-01
#
# At iterate  680    f= -1.80691D+02    |proj g|=  2.62063D-01
#
# At iterate  681    f= -1.80703D+02    |proj g|=  3.45998D-01
#
# At iterate  682    f= -1.80709D+02    |proj g|=  3.48249D-01
#
# At iterate  683    f= -1.80718D+02    |proj g|=  2.97854D-01
#
# At iterate  684    f= -1.80729D+02    |proj g|=  3.31151D-01
#
# At iterate  685    f= -1.80737D+02    |proj g|=  3.69228D-01
#
# At iterate  686    f= -1.80750D+02    |proj g|=  4.24602D-01
#
# At iterate  687    f= -1.80755D+02    |proj g|=  3.57792D-01
#
# At iterate  688    f= -1.80766D+02    |proj g|=  3.56965D-01
#
# At iterate  689    f= -1.80770D+02    |proj g|=  4.53024D-01
#
# At iterate  690    f= -1.80780D+02    |proj g|=  3.01412D-01
#
# At iterate  691    f= -1.80794D+02    |proj g|=  3.63650D-01
#
# At iterate  692    f= -1.80807D+02    |proj g|=  3.71348D-01
#
# At iterate  693    f= -1.80827D+02    |proj g|=  4.00377D-01
#
# At iterate  694    f= -1.80855D+02    |proj g|=  3.34893D-01
#
# At iterate  695    f= -1.80870D+02    |proj g|=  3.12148D-01
#
# At iterate  696    f= -1.80891D+02    |proj g|=  5.04028D-01
#
# At iterate  697    f= -1.80918D+02    |proj g|=  4.38864D-01
#
# At iterate  698    f= -1.80957D+02    |proj g|=  2.94569D-01
#
# At iterate  699    f= -1.80977D+02    |proj g|=  3.76011D-01
#
# At iterate  700    f= -1.80992D+02    |proj g|=  3.88621D-01
#
# At iterate  701    f= -1.80996D+02    |proj g|=  3.52515D-01
#
# At iterate  702    f= -1.81008D+02    |proj g|=  2.76481D-01
#
# At iterate  703    f= -1.81028D+02    |proj g|=  4.30080D-01
#
# At iterate  704    f= -1.81041D+02    |proj g|=  5.35525D-01
#
# At iterate  705    f= -1.81057D+02    |proj g|=  4.56997D-01
#
# At iterate  706    f= -1.81066D+02    |proj g|=  5.37007D-01
#
# At iterate  707    f= -1.81081D+02    |proj g|=  3.52176D-01
#
# At iterate  708    f= -1.81098D+02    |proj g|=  3.87744D-01
#
# At iterate  709    f= -1.81100D+02    |proj g|=  3.90018D-01
#
# At iterate  710    f= -1.81126D+02    |proj g|=  4.25595D-01
#
# At iterate  711    f= -1.81147D+02    |proj g|=  6.75499D-01
#
# At iterate  712    f= -1.81167D+02    |proj g|=  5.95534D-01
#
# At iterate  713    f= -1.81168D+02    |proj g|=  7.11058D-01
#
# At iterate  714    f= -1.81195D+02    |proj g|=  5.25713D-01
#
# At iterate  715    f= -1.81213D+02    |proj g|=  3.25587D-01
#
# At iterate  716    f= -1.81220D+02    |proj g|=  5.05889D-01
#
# At iterate  717    f= -1.81225D+02    |proj g|=  6.25645D-01
#
# At iterate  718    f= -1.81231D+02    |proj g|=  4.11799D-01
#
# At iterate  719    f= -1.81235D+02    |proj g|=  2.37904D-01
#
# At iterate  720    f= -1.81238D+02    |proj g|=  3.01883D-01
#
# At iterate  721    f= -1.81248D+02    |proj g|=  2.40688D-01
#
# At iterate  722    f= -1.81257D+02    |proj g|=  4.29834D-01
#
# At iterate  723    f= -1.81262D+02    |proj g|=  5.52588D-01
#
# At iterate  724    f= -1.81266D+02    |proj g|=  3.08709D-01
#
# At iterate  725    f= -1.81279D+02    |proj g|=  3.22939D-01
#
# At iterate  726    f= -1.81286D+02    |proj g|=  3.61347D-01
#
# At iterate  727    f= -1.81293D+02    |proj g|=  4.23870D-01
#
# At iterate  728    f= -1.81299D+02    |proj g|=  3.83393D-01
#
# At iterate  729    f= -1.81309D+02    |proj g|=  5.30175D-01
#
# At iterate  730    f= -1.81319D+02    |proj g|=  6.27305D-01
#
# At iterate  731    f= -1.81341D+02    |proj g|=  1.99039D-01
#
# At iterate  732    f= -1.81347D+02    |proj g|=  4.75451D-01
#
# At iterate  733    f= -1.81356D+02    |proj g|=  3.58777D-01
#
# At iterate  734    f= -1.81365D+02    |proj g|=  3.75570D-01
#
# At iterate  735    f= -1.81380D+02    |proj g|=  3.74715D-01
#
# At iterate  736    f= -1.81402D+02    |proj g|=  3.71425D-01
#
# At iterate  737    f= -1.81417D+02    |proj g|=  4.50733D-01
#
# At iterate  738    f= -1.81427D+02    |proj g|=  2.82000D-01
#
# At iterate  739    f= -1.81442D+02    |proj g|=  2.85738D-01
#
# At iterate  740    f= -1.81451D+02    |proj g|=  4.87589D-01
#
# At iterate  741    f= -1.81468D+02    |proj g|=  3.94892D-01
#
# At iterate  742    f= -1.81471D+02    |proj g|=  4.55226D-01
#
# At iterate  743    f= -1.81483D+02    |proj g|=  4.54555D-01
#
# At iterate  744    f= -1.81501D+02    |proj g|=  6.51291D-01
#
# At iterate  745    f= -1.81520D+02    |proj g|=  4.08135D-01
#
# At iterate  746    f= -1.81528D+02    |proj g|=  4.00378D-01
#
# At iterate  747    f= -1.81536D+02    |proj g|=  1.99235D-01
#
# At iterate  748    f= -1.81543D+02    |proj g|=  2.93961D-01
#
# At iterate  749    f= -1.81545D+02    |proj g|=  3.61262D-01
#
# At iterate  750    f= -1.81549D+02    |proj g|=  3.00029D-01
#
# At iterate  751    f= -1.81551D+02    |proj g|=  3.62104D-01
#
# At iterate  752    f= -1.81557D+02    |proj g|=  2.94828D-01
#
# At iterate  753    f= -1.81567D+02    |proj g|=  3.42739D-01
#
# At iterate  754    f= -1.81572D+02    |proj g|=  2.78485D-01
#
# At iterate  755    f= -1.81578D+02    |proj g|=  2.42858D-01
#
# At iterate  756    f= -1.81586D+02    |proj g|=  3.65445D-01
#
# At iterate  757    f= -1.81590D+02    |proj g|=  3.76835D-01
#
# At iterate  758    f= -1.81604D+02    |proj g|=  4.02482D-01
#
# At iterate  759    f= -1.81620D+02    |proj g|=  2.93819D-01
#
# At iterate  760    f= -1.81637D+02    |proj g|=  4.54861D-01
#
# At iterate  761    f= -1.81651D+02    |proj g|=  4.26893D-01
#
# At iterate  762    f= -1.81671D+02    |proj g|=  4.98553D-01
#
# At iterate  763    f= -1.81682D+02    |proj g|=  3.49389D-01
#
# At iterate  764    f= -1.81693D+02    |proj g|=  3.81131D-01
#
# At iterate  765    f= -1.81701D+02    |proj g|=  2.91618D-01
#
# At iterate  766    f= -1.81708D+02    |proj g|=  3.33769D-01
#
# At iterate  767    f= -1.81710D+02    |proj g|=  3.41142D-01
#
# At iterate  768    f= -1.81720D+02    |proj g|=  3.91549D-01
#
# At iterate  769    f= -1.81722D+02    |proj g|=  4.80989D-01
#
# At iterate  770    f= -1.81733D+02    |proj g|=  3.27059D-01
#
# ...
#
# At iterate 1669    f= -1.84379D+02    |proj g|=  3.13968D-01
#
# At iterate 1670    f= -1.84380D+02    |proj g|=  2.53951D-01
#
# At iterate 1671    f= -1.84381D+02    |proj g|=  1.31942D-01
#
# At iterate 1672    f= -1.84382D+02    |proj g|=  1.54378D-01
#
# At iterate 1673    f= -1.84383D+02    |proj g|=  1.60192D-01
#
# At iterate 1674    f= -1.84383D+02    |proj g|=  1.72797D-01
#
# At iterate 1675    f= -1.84384D+02    |proj g|=  1.87142D-01
#
# At iterate 1676    f= -1.84385D+02    |proj g|=  1.79115D-01
#
# At iterate 1677    f= -1.84386D+02    |proj g|=  2.61352D-01
#
# At iterate 1678    f= -1.84388D+02    |proj g|=  1.87488D-01
#
# At iterate 1679    f= -1.84390D+02    |proj g|=  2.47535D-01
#
# At iterate 1680    f= -1.84391D+02    |proj g|=  2.44010D-01
#
# At iterate 1681    f= -1.84393D+02    |proj g|=  1.50137D-01
#
# At iterate 1682    f= -1.84394D+02    |proj g|=  2.88560D-01
#
# At iterate 1683    f= -1.84394D+02    |proj g|=  2.87505D-01
#
# At iterate 1684    f= -1.84395D+02    |proj g|=  2.29820D-01
#
# At iterate 1685    f= -1.84397D+02    |proj g|=  2.63521D-01
#
# At iterate 1686    f= -1.84397D+02    |proj g|=  2.62673D-01
#
# At iterate 1687    f= -1.84398D+02    |proj g|=  1.98490D-01
#
# At iterate 1688    f= -1.84399D+02    |proj g|=  1.89598D-01
#
# At iterate 1689    f= -1.84401D+02    |proj g|=  1.92333D-01
#
# At iterate 1690    f= -1.84405D+02    |proj g|=  2.50595D-01
#
# At iterate 1691    f= -1.84409D+02    |proj g|=  2.54461D-01
#
# At iterate 1692    f= -1.84413D+02    |proj g|=  2.64302D-01
#
# At iterate 1693    f= -1.84416D+02    |proj g|=  2.13999D-01
#
# At iterate 1694    f= -1.84418D+02    |proj g|=  1.66790D-01
#
# At iterate 1695    f= -1.84421D+02    |proj g|=  2.19918D-01
#
# At iterate 1696    f= -1.84423D+02    |proj g|=  4.35120D-01
#
# At iterate 1697    f= -1.84426D+02    |proj g|=  2.98677D-01
#
# At iterate 1698    f= -1.84428D+02    |proj g|=  1.68562D-01
#
# At iterate 1699    f= -1.84429D+02    |proj g|=  2.27482D-01
#
# At iterate 1700    f= -1.84431D+02    |proj g|=  2.04928D-01
#
# At iterate 1701    f= -1.84431D+02    |proj g|=  2.68577D-01
#
# At iterate 1702    f= -1.84433D+02    |proj g|=  2.10410D-01
#
# At iterate 1703    f= -1.84433D+02    |proj g|=  1.73697D-01
#
# At iterate 1704    f= -1.84435D+02    |proj g|=  2.19379D-01
#
# At iterate 1705    f= -1.84436D+02    |proj g|=  2.35752D-01
#
# At iterate 1706    f= -1.84437D+02    |proj g|=  1.85349D-01
#
# At iterate 1707    f= -1.84438D+02    |proj g|=  2.26819D-01
#
# At iterate 1708    f= -1.84440D+02    |proj g|=  1.44956D-01
#
# At iterate 1709    f= -1.84442D+02    |proj g|=  2.61369D-01
#
# At iterate 1710    f= -1.84445D+02    |proj g|=  1.79501D-01
#
# At iterate 1711    f= -1.84447D+02    |proj g|=  2.63755D-01
#
# At iterate 1712    f= -1.84449D+02    |proj g|=  2.45379D-01
#
# At iterate 1713    f= -1.84452D+02    |proj g|=  1.61444D-01
#
# At iterate 1714    f= -1.84453D+02    |proj g|=  2.26101D-01
#
# At iterate 1715    f= -1.84455D+02    |proj g|=  1.65559D-01
#
# At iterate 1716    f= -1.84457D+02    |proj g|=  1.48750D-01
#
# At iterate 1717    f= -1.84458D+02    |proj g|=  1.77177D-01
#
# At iterate 1718    f= -1.84459D+02    |proj g|=  3.27416D-01
#
# At iterate 1719    f= -1.84460D+02    |proj g|=  1.45805D-01
#
# At iterate 1720    f= -1.84462D+02    |proj g|=  2.44288D-01
#
# At iterate 1721    f= -1.84463D+02    |proj g|=  2.08955D-01
#
# At iterate 1722    f= -1.84465D+02    |proj g|=  1.31506D-01
#
# At iterate 1723    f= -1.84466D+02    |proj g|=  2.33357D-01
#
# At iterate 1724    f= -1.84469D+02    |proj g|=  3.12013D-01
#
# At iterate 1725    f= -1.84471D+02    |proj g|=  1.64166D-01
#
# At iterate 1726    f= -1.84472D+02    |proj g|=  1.46950D-01
#
# At iterate 1727    f= -1.84474D+02    |proj g|=  3.39723D-01
#
# At iterate 1728    f= -1.84476D+02    |proj g|=  2.45778D-01
#
# At iterate 1729    f= -1.84478D+02    |proj g|=  2.68791D-01
#
# At iterate 1730    f= -1.84481D+02    |proj g|=  2.55503D-01
#
# At iterate 1731    f= -1.84484D+02    |proj g|=  2.17309D-01
#
# At iterate 1732    f= -1.84487D+02    |proj g|=  2.02207D-01
#
# At iterate 1733    f= -1.84489D+02    |proj g|=  3.42919D-01
#
# At iterate 1734    f= -1.84491D+02    |proj g|=  2.14831D-01
#
# At iterate 1735    f= -1.84493D+02    |proj g|=  2.71709D-01
#
# At iterate 1736    f= -1.84495D+02    |proj g|=  2.30310D-01
#
# At iterate 1737    f= -1.84496D+02    |proj g|=  2.30276D-01
#
# At iterate 1738    f= -1.84499D+02    |proj g|=  2.10073D-01
#
# At iterate 1739    f= -1.84503D+02    |proj g|=  2.88271D-01
#
# At iterate 1740    f= -1.84506D+02    |proj g|=  1.94255D-01
#
# At iterate 1741    f= -1.84508D+02    |proj g|=  2.81244D-01
#
# At iterate 1742    f= -1.84510D+02    |proj g|=  3.80620D-01
#
# At iterate 1743    f= -1.84514D+02    |proj g|=  5.22798D-01
#
# At iterate 1744    f= -1.84519D+02    |proj g|=  3.11798D-01
#
# At iterate 1745    f= -1.84524D+02    |proj g|=  3.65557D-01
#
# At iterate 1746    f= -1.84528D+02    |proj g|=  4.19530D-01
#
# At iterate 1747    f= -1.84531D+02    |proj g|=  2.88104D-01
#
# At iterate 1748    f= -1.84535D+02    |proj g|=  2.66133D-01
#
# At iterate 1749    f= -1.84537D+02    |proj g|=  2.07857D-01
#
# At iterate 1750    f= -1.84539D+02    |proj g|=  2.81658D-01
#
# At iterate 1751    f= -1.84541D+02    |proj g|=  2.51732D-01
#
# At iterate 1752    f= -1.84544D+02    |proj g|=  2.02742D-01
#
# At iterate 1753    f= -1.84546D+02    |proj g|=  4.22929D-01
#
# At iterate 1754    f= -1.84550D+02    |proj g|=  3.22860D-01
#
# At iterate 1755    f= -1.84552D+02    |proj g|=  2.96923D-01
#
# At iterate 1756    f= -1.84554D+02    |proj g|=  2.51667D-01
#
# At iterate 1757    f= -1.84554D+02    |proj g|=  4.21963D-01
#
# At iterate 1758    f= -1.84556D+02    |proj g|=  2.40806D-01
#
# At iterate 1759    f= -1.84556D+02    |proj g|=  1.71668D-01
#
# At iterate 1760    f= -1.84557D+02    |proj g|=  1.50373D-01
#
# At iterate 1761    f= -1.84557D+02    |proj g|=  1.93786D-01
#
# At iterate 1762    f= -1.84558D+02    |proj g|=  1.59912D-01
#
# At iterate 1763    f= -1.84559D+02    |proj g|=  1.74042D-01
#
# At iterate 1764    f= -1.84559D+02    |proj g|=  3.66316D-01
#
# At iterate 1765    f= -1.84561D+02    |proj g|=  2.75680D-01
#
# At iterate 1766    f= -1.84563D+02    |proj g|=  2.14276D-01
#
# At iterate 1767    f= -1.84565D+02    |proj g|=  1.82507D-01
#
# At iterate 1768    f= -1.84566D+02    |proj g|=  3.22585D-01
#
# At iterate 1769    f= -1.84568D+02    |proj g|=  1.49793D-01
#
# At iterate 1770    f= -1.84569D+02    |proj g|=  1.83313D-01
#
# At iterate 1771    f= -1.84570D+02    |proj g|=  1.40676D-01
#
# At iterate 1772    f= -1.84571D+02    |proj g|=  1.92972D-01
#
# At iterate 1773    f= -1.84572D+02    |proj g|=  2.03308D-01
#
# At iterate 1774    f= -1.84574D+02    |proj g|=  3.32321D-01
#
# At iterate 1775    f= -1.84576D+02    |proj g|=  2.19249D-01
#
# At iterate 1776    f= -1.84578D+02    |proj g|=  1.32123D-01
#
# At iterate 1777    f= -1.84580D+02    |proj g|=  1.80348D-01
#
# At iterate 1778    f= -1.84583D+02    |proj g|=  2.58358D-01
#
# At iterate 1779    f= -1.84585D+02    |proj g|=  2.22846D-01
#
# At iterate 1780    f= -1.84588D+02    |proj g|=  2.44370D-01
#
# At iterate 1781    f= -1.84591D+02    |proj g|=  2.69258D-01
#
# At iterate 1782    f= -1.84594D+02    |proj g|=  2.98136D-01
#
# At iterate 1783    f= -1.84599D+02    |proj g|=  3.88637D-01
#
# At iterate 1784    f= -1.84601D+02    |proj g|=  2.76278D-01
#
# At iterate 1785    f= -1.84604D+02    |proj g|=  2.18346D-01
#
# At iterate 1786    f= -1.84605D+02    |proj g|=  3.84489D-01
#
# At iterate 1787    f= -1.84608D+02    |proj g|=  2.10389D-01
#
# At iterate 1788    f= -1.84609D+02    |proj g|=  2.70787D-01
#
# At iterate 1789    f= -1.84612D+02    |proj g|=  1.97305D-01
#
# At iterate 1790    f= -1.84613D+02    |proj g|=  1.73331D-01
#
# At iterate 1791    f= -1.84614D+02    |proj g|=  3.77132D-01
#
# At iterate 1792    f= -1.84616D+02    |proj g|=  2.51651D-01
#
# At iterate 1793    f= -1.84618D+02    |proj g|=  1.43824D-01
#
# At iterate 1794    f= -1.84618D+02    |proj g|=  1.88976D-01
#
# At iterate 1795    f= -1.84620D+02    |proj g|=  3.42106D-01
#
# At iterate 1796    f= -1.84622D+02    |proj g|=  1.79980D-01
#
# At iterate 1797    f= -1.84624D+02    |proj g|=  1.40387D-01
#
# At iterate 1798    f= -1.84627D+02    |proj g|=  3.10342D-01
#
# At iterate 1799    f= -1.84631D+02    |proj g|=  2.28757D-01
#
# At iterate 1800    f= -1.84633D+02    |proj g|=  3.26735D-01
#
# At iterate 1801    f= -1.84635D+02    |proj g|=  2.20790D-01
#
# At iterate 1802    f= -1.84639D+02    |proj g|=  3.07962D-01
#
# At iterate 1803    f= -1.84642D+02    |proj g|=  3.36168D-01
#
# At iterate 1804    f= -1.84644D+02    |proj g|=  3.56763D-01
#
# At iterate 1805    f= -1.84646D+02    |proj g|=  2.75277D-01
#
# At iterate 1806    f= -1.84651D+02    |proj g|=  2.68010D-01
#
# At iterate 1807    f= -1.84652D+02    |proj g|=  1.36267D-01
#
# At iterate 1808    f= -1.84653D+02    |proj g|=  1.45961D-01
#
# At iterate 1809    f= -1.84655D+02    |proj g|=  2.00230D-01
#
# At iterate 1810    f= -1.84657D+02    |proj g|=  2.09247D-01
#
# At iterate 1811    f= -1.84658D+02    |proj g|=  1.63963D-01
#
# At iterate 1812    f= -1.84659D+02    |proj g|=  2.98360D-01
#
# At iterate 1813    f= -1.84661D+02    |proj g|=  1.82409D-01
#
# At iterate 1814    f= -1.84662D+02    |proj g|=  2.14233D-01
#
# At iterate 1815    f= -1.84663D+02    |proj g|=  1.71595D-01
#
# At iterate 1816    f= -1.84664D+02    |proj g|=  1.33061D-01
#
# At iterate 1817    f= -1.84665D+02    |proj g|=  1.47154D-01
#
# At iterate 1818    f= -1.84666D+02    |proj g|=  2.37310D-01
#
# At iterate 1819    f= -1.84667D+02    |proj g|=  2.70203D-01
#
# At iterate 1820    f= -1.84668D+02    |proj g|=  3.71345D-01
#
# At iterate 1821    f= -1.84670D+02    |proj g|=  2.99487D-01
#
# At iterate 1822    f= -1.84672D+02    |proj g|=  1.89449D-01
#
# At iterate 1823    f= -1.84675D+02    |proj g|=  2.48968D-01
#
# At iterate 1824    f= -1.84677D+02    |proj g|=  2.12752D-01
#
# At iterate 1825    f= -1.84679D+02    |proj g|=  2.63301D-01
#
# At iterate 1826    f= -1.84680D+02    |proj g|=  2.48601D-01
#
# At iterate 1827    f= -1.84683D+02    |proj g|=  2.58125D-01
#
# At iterate 1828    f= -1.84685D+02    |proj g|=  2.20134D-01
#
# At iterate 1829    f= -1.84688D+02    |proj g|=  2.12652D-01
#
# At iterate 1830    f= -1.84689D+02    |proj g|=  3.50817D-01
#
# At iterate 1831    f= -1.84691D+02    |proj g|=  3.10638D-01
#
# At iterate 1832    f= -1.84692D+02    |proj g|=  4.46696D-01
#
# At iterate 1833    f= -1.84695D+02    |proj g|=  2.74138D-01
#
# At iterate 1834    f= -1.84696D+02    |proj g|=  1.69327D-01
#
# At iterate 1835    f= -1.84697D+02    |proj g|=  2.85423D-01
#
# At iterate 1836    f= -1.84700D+02    |proj g|=  2.83816D-01
#
# At iterate 1837    f= -1.84703D+02    |proj g|=  3.83496D-01
#
# At iterate 1838    f= -1.84705D+02    |proj g|=  2.92457D-01
#
# At iterate 1839    f= -1.84708D+02    |proj g|=  2.28741D-01
#
# At iterate 1840    f= -1.84711D+02    |proj g|=  2.29708D-01
#
# At iterate 1841    f= -1.84714D+02    |proj g|=  2.43414D-01
#
# At iterate 1842    f= -1.84717D+02    |proj g|=  2.65281D-01
#
# At iterate 1843    f= -1.84718D+02    |proj g|=  4.08754D-01
#
# At iterate 1844    f= -1.84721D+02    |proj g|=  2.13518D-01
#
# At iterate 1845    f= -1.84723D+02    |proj g|=  1.94838D-01
#
# At iterate 1846    f= -1.84725D+02    |proj g|=  2.58299D-01
#
# At iterate 1847    f= -1.84725D+02    |proj g|=  1.76518D-01
#
# At iterate 1848    f= -1.84727D+02    |proj g|=  1.89767D-01
#
# At iterate 1849    f= -1.84727D+02    |proj g|=  1.68154D-01
#
# At iterate 1850    f= -1.84728D+02    |proj g|=  1.32459D-01
#
# At iterate 1851    f= -1.84729D+02    |proj g|=  2.85303D-01
#
# At iterate 1852    f= -1.84730D+02    |proj g|=  2.54477D-01
#
# At iterate 1853    f= -1.84731D+02    |proj g|=  1.99561D-01
#
# At iterate 1854    f= -1.84732D+02    |proj g|=  2.01273D-01
#
# At iterate 1855    f= -1.84734D+02    |proj g|=  2.19628D-01
#
# At iterate 1856    f= -1.84737D+02    |proj g|=  2.34649D-01
#
# At iterate 1857    f= -1.84738D+02    |proj g|=  3.59787D-01
#
# At iterate 1858    f= -1.84741D+02    |proj g|=  2.15892D-01
#
# At iterate 1859    f= -1.84743D+02    |proj g|=  3.62320D-01
#
# At iterate 1860    f= -1.84745D+02    |proj g|=  2.40465D-01
#
# At iterate 1861    f= -1.84750D+02    |proj g|=  1.74667D-01
#
# At iterate 1862    f= -1.84752D+02    |proj g|=  2.17342D-01
#
# At iterate 1863    f= -1.84753D+02    |proj g|=  3.40488D-01
#
# At iterate 1864    f= -1.84755D+02    |proj g|=  1.52598D-01
#
# At iterate 1865    f= -1.84757D+02    |proj g|=  3.11419D-01
#
# At iterate 1866    f= -1.84759D+02    |proj g|=  2.36630D-01
#
# At iterate 1867    f= -1.84761D+02    |proj g|=  1.87485D-01
#
# At iterate 1868    f= -1.84762D+02    |proj g|=  3.87823D-01
#
# At iterate 1869    f= -1.84764D+02    |proj g|=  3.68012D-01
#
# At iterate 1870    f= -1.84766D+02    |proj g|=  2.69185D-01
#
# At iterate 1871    f= -1.84767D+02    |proj g|=  2.30864D-01
#
# At iterate 1872    f= -1.84770D+02    |proj g|=  2.28207D-01
#
# At iterate 1873    f= -1.84771D+02    |proj g|=  3.55183D-01
#
# At iterate 1874    f= -1.84774D+02    |proj g|=  2.95534D-01
#
# At iterate 1875    f= -1.84778D+02    |proj g|=  3.45833D-01
#
# At iterate 1876    f= -1.84780D+02    |proj g|=  2.30299D-01
#
# At iterate 1877    f= -1.84782D+02    |proj g|=  4.54546D-01
#
# At iterate 1878    f= -1.84786D+02    |proj g|=  2.29238D-01
#
# At iterate 1879    f= -1.84789D+02    |proj g|=  4.57308D-01
#
# At iterate 1880    f= -1.84792D+02    |proj g|=  3.37678D-01
#
# At iterate 1881    f= -1.84797D+02    |proj g|=  2.79767D-01
#
# At iterate 1882    f= -1.84800D+02    |proj g|=  2.78500D-01
#
# At iterate 1883    f= -1.84803D+02    |proj g|=  4.12256D-01
#
# At iterate 1884    f= -1.84806D+02    |proj g|=  4.70451D-01
#
# At iterate 1885    f= -1.84809D+02    |proj g|=  2.57293D-01
#
# At iterate 1886    f= -1.84812D+02    |proj g|=  3.23143D-01
#
# At iterate 1887    f= -1.84815D+02    |proj g|=  2.18372D-01
#
# At iterate 1888    f= -1.84816D+02    |proj g|=  3.66199D-01
#
# At iterate 1889    f= -1.84818D+02    |proj g|=  1.89519D-01
#
# At iterate 1890    f= -1.84819D+02    |proj g|=  1.81265D-01
#
# At iterate 1891    f= -1.84821D+02    |proj g|=  1.37149D-01
#
# At iterate 1892    f= -1.84822D+02    |proj g|=  2.81941D-01
#
# At iterate 1893    f= -1.84824D+02    |proj g|=  2.08292D-01
#
# At iterate 1894    f= -1.84826D+02    |proj g|=  2.29380D-01
#
# At iterate 1895    f= -1.84826D+02    |proj g|=  2.89594D-01
#
# At iterate 1896    f= -1.84829D+02    |proj g|=  2.60259D-01
#
# At iterate 1897    f= -1.84830D+02    |proj g|=  2.57702D-01
#
# At iterate 1898    f= -1.84832D+02    |proj g|=  1.50672D-01
#
# At iterate 1899    f= -1.84833D+02    |proj g|=  4.09268D-01
#
# At iterate 1900    f= -1.84834D+02    |proj g|=  3.63342D-01
#
# At iterate 1901    f= -1.84835D+02    |proj g|=  3.53594D-01
#
# At iterate 1902    f= -1.84836D+02    |proj g|=  2.42659D-01
#
# At iterate 1903    f= -1.84837D+02    |proj g|=  2.08715D-01
#
# At iterate 1904    f= -1.84837D+02    |proj g|=  2.90342D-01
#
# At iterate 1905    f= -1.84838D+02    |proj g|=  1.84697D-01
#
# At iterate 1906    f= -1.84840D+02    |proj g|=  2.05623D-01
#
# At iterate 1907    f= -1.84841D+02    |proj g|=  3.75696D-01
#
# At iterate 1908    f= -1.84843D+02    |proj g|=  2.31375D-01
#
# At iterate 1909    f= -1.84845D+02    |proj g|=  2.85388D-01
#
# At iterate 1910    f= -1.84847D+02    |proj g|=  1.46657D-01
#
# At iterate 1911    f= -1.84848D+02    |proj g|=  3.84173D-01
#
# At iterate 1912    f= -1.84849D+02    |proj g|=  3.44685D-01
#
# At iterate 1913    f= -1.84850D+02    |proj g|=  1.03158D-01
#
# At iterate 1914    f= -1.84850D+02    |proj g|=  9.78299D-02
#
# At iterate 1915    f= -1.84851D+02    |proj g|=  1.06642D-01
# LBFGSB time : 6.885422945022583
# At iterate 1916    f= -1.84851D+02    |proj g|=  3.88265D-01
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   350   1916   2072   2140     0     7   3.883D-01  -1.849D+02
#   F =  -184.85110006935628
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
W_A_B = res[0]
W = W_A_B[:m*p**2].reshape((m, p, p))
A = 1 / (W_A_B[m*p**2: m*p*(p+1)].reshape((m, p)) / (dilation_scale * time_params_scale))
B = -W_A_B[m*p*(p+1):].reshape((m, p)) / time_params_scale

memory_W = np.array(callback.memory_W)
memory_A = np.array(callback.memory_A)
memory_B = np.array(callback.memory_B)

# %% [markdown]
# # plot dilations and shifts

# %%
# Linear regression
slope_A, intercept_A, _, _, _ = stats.linregress(dilations.ravel(), A.ravel())
slope_B, intercept_B, _, _, _ = stats.linregress(shifts.ravel(), B.ravel())

# R2 scores
r2_A = r2_score(dilations.ravel(), A.ravel())
r2_B = r2_score(shifts.ravel(), B.ravel())

# pvalues
pvalue_A = stats.pearsonr(dilations.ravel(), A.ravel())[1]
pvalue_B = stats.pearsonr(shifts.ravel(), B.ravel())[1]

# %%
# colors
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# scatter plots
plt.subplots(1, 2, figsize=(8, 4))

plt.subplot(1, 2, 1)
for i in range(p):
    plt.scatter(shifts[:, i], B[:, i], c=colors[i], label=f"source {i}")
plt.title(f"Shifts\nR2={r2_B:.3f} ; p-value={pvalue_B:.3}")
plt.xlabel("True shifts")
plt.ylabel("Estimated shifts")
plt.legend()
# diagonal
xmin, xmax = plt.xlim()
ymin, ymax = plt.ylim()
plt.plot([xmin, xmax], [xmin, xmax], c='k', linestyle='--')
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
# fitLine
shifts_abs = np.linspace(xmin, xmax, 2)
fitLine_B = slope_B * shifts_abs + intercept_B
plt.plot(shifts_abs, fitLine_B, c="grey", linestyle='--')

plt.subplot(1, 2, 2)
for i in range(p):
    plt.scatter(dilations[:, i], A[:, i], c=colors[i])
plt.title(f"Dilations\nR2={r2_A:.3f} ; p-value={pvalue_A:.3}")
plt.xlabel("True dilations")
plt.ylabel("Estimated dilations")
# diagonal
xmin, xmax = plt.xlim()
ymin, ymax = plt.ylim()
plt.plot([xmin, xmax], [xmin, xmax], c='k', linestyle='--', label="diagonal")
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
# fitLine
dilations_abs = np.linspace(xmin, xmax, 2)
fitLine_A = slope_A * dilations_abs + intercept_A
plt.plot(dilations_abs, fitLine_A, c="grey", linestyle='--', label="fitLine")
plt.legend()

plt.suptitle(f"With total loss\nEstimated shifts and dilations ; noise S_list = {noise_data} ; noise W_list = {noise_W_list}")
plt.tight_layout()
plt.show()

# %%
source_number = 4

plt.subplots(1, 2, figsize=(12, 4))

plt.subplot(1, 2, 1)
for i in range(m):
    plt.plot(-memory_B[:, i, source_number], label=f"subject {i}")
plt.grid()
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("Estimated shifts")
plt.title(f"Shifts across iterations")

plt.subplot(1, 2, 2)
for i in range(m):
    plt.plot(1/memory_A[:, i, source_number])
plt.grid()
plt.xlabel("Iterations")
plt.ylabel("Estimated dilations")
plt.title(f"Dilations across iterations")

plt.suptitle(f"Estimated dilations and shifts across iterations for the source {source_number}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # MVICAD

# %%
# MVICAD
_, W_mvicad, _, _, _, _ = multiviewica_delay(
    X_list,
    init=W_list_init,
    shared_delays=False,
    max_delay=int(max_shift),
    random_state=random_state,
    continuous_delays=False,
)

# %% [markdown]
# # Amari distance

# %%
amari_mvicad = np.mean([amari_distance(W, A) for W, A in zip(W_mvicad, A_list)])
print(f"Amari distance MVICAD : {amari_mvicad}")
# Out:
# Amari distance MVICAD : 0.4334937483853226

# %%
W_list_rand = rng.randn(m, p, p)
amari_rand = np.mean([amari_distance(W, A) for W, A in zip(W_list_rand, A_list)])
print(f"Amari distance random : {amari_rand}")
# Out:
# Amari distance random : 0.8507165826816616

# %%
amari_distances = []
for W_list in tqdm(callback.memory_W):
    amari_distances.append(np.mean([amari_distance(W, A) for W, A in zip(W_list, A_list)]))
# Out:
# 100%|██████████| 1916/1916 [00:00<00:00, 2331.32it/s]

# %%
plt.figure(figsize=(8, 6))
plt.plot(amari_distances, label="LBFGSB")
xmin, xmax = plt.xlim()
plt.hlines(y=amari_mvicad, xmin=xmin, xmax=xmax, linestyles='--', colors='grey', label="MVICAD")
plt.hlines(y=amari_rand, xmin=xmin, xmax=xmax, linestyles='--', colors='k', label="random")
plt.yscale('log')
plt.xlabel("Iterations")
plt.ylabel("Amari distance")
plt.title("Amari distance across iterations")
plt.xlim([xmin, xmax])
plt.legend()
plt.grid()
